# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Monday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**
#
# **Please check that the link you submitted can be opened and points to the correct assignment.**

# %% [markdown]
# # Question 1 (25 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
#
# (3) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (4) Collect all the information of the 904 narrators in the Densho Digital Repository.
#
# (5)**Collect a total of 10000 reviews** of the top 100 most popular software from G2 and Capterra.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Your code here

def scrape_imdb_reviews(no_of_reviews=1000):
    base_url = 'https://www.imdb.com/title/tt15239678/reviews'
    reviews = []
    page_num = 0  # Adjust pagination based on IMDb's structure

    while len(reviews) < no_of_reviews:
        url = f'{base_url}?start={page_num}'
        response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract review text using the identified class
        review_containers = soup.find_all('div', class_='ipc-html-content ipc-html-content--base')
        for container in review_containers:
            inner_div = container.find('div', class_='ipc-html-content-inner-div')
            if inner_div:
                reviews.append(inner_div.text.strip())

        page_num += 25  # Increment by 25 for pagination

    return reviews[:no_of_reviews]

# Scraping top 1000 user reviews
dune_Part2_reviews = scrape_imdb_reviews(1000)
print(dune_Part2_reviews[:5])
print(len(dune_Part2_reviews))
# Out:
# ['Had the pleasure to watch this film in an early screening and was completely blown away."Dune: Part 2" is everything one could ask for from a film of its kind. As a big fan of the Game of Thrones franchise, it\'s been a long time since iv\'e encountered this level of world-building and epicness. The plot and story development are carried out in an awe-inspiring manner throughout the movie, progressing at a precise pace toward a spectacular climax that is executed perfectly.Denis Villeneuve continues to prove himself as one of the most promising filmmakers of our time, and if it was up to me I would keep him in these high-budget epic tales such as these since there are very few directors working today that can tackle this genre as good as he does. The film received praise from many great filmmakers, the most notable being Christopher Nolan (The Dark Knight Trilogy, Oppenheimer), who very accurately compared Villeneuve\'s achievement in this film to the "Empire Strikes Back" of the modern era.Would highly recommend to re-watch the first movie in order to appreciate the subtleties and foreshadowing better, though it\'s not completely necessary since the movie is pretty self-contained. More specifically, one of the most prominent and impressive strengths of the movie is how it stands on its own without relying too heavily on the first part. Of course, for those who really want to enjoy the story, there\'s no real point in watching the second part without having seen the first one. However, even those who watched it a few years ago and don\'t remember every little plot detail will be able to catch up very quickly while watching the Pt. 2 and will understand all the important details-even the smaller ones. Non-ideally, even someone who hasn\'t watched the first movie at all will greatly enjoy this one, as it is very self-contained despite relying heavily on the first movie-an impressive and highly commendable screenplay effort by the writers.Timothée Chalamet delivers a very impressive and charismatic performance, to the point where it seems like this is the role he was born to play. Zendaya also gives a very good performance, with significantly more screen time than in the first movie. Austin Butler manages to be terrifying in the role of the villain, Rebecca Ferguson shines in one of the best performances of the year, and Javier Bardem surprises in a role that sometimes provides the comic relief of the movie. In addition to them, the film is filled with top-tier actors and actresses who all perform their roles amazingly.Hans Zimmer\'s score is masterful just as you\'d expect, and one step up from the Oscar winning and Grammy nominated score of Pt. 1. Technical aspects such as VFX, Production Design, Sound, Editing, etc. Are all top notch and awards-worthy. The action sequences are absolutely mind blowing and sent chills down my spine. Denis direction is impeccable, and the story is absolutely fascinating- continuing to develop characters from Pt. 1 even deeper and introduce new incredible and intriguing characters.In my personal opinion, the movie is better than the first part in pretty much every aspect. While the first part was excellent, it mainly served as a setup and positioning of the pieces for the sequel. In "Part 2," the story reaches its climax, with one of the strongest climaxes seen on the big screen in recent decades, befitting the complex work Frank Herbert wrote many years ago.I believe (and surely hope) this movie will be a major player in the next Award Season. Below-the-line wins are pretty much guaranteed as of now, but I hope it will get some love in above-the-line categories such as Direction and even Best Picture, perhaps to break stigmas presented against the Fantasy/Sci-Fi genre in recent years at the Academy. As a big fan of the genre, unless a better competitor will be released later this eligibility period, maybe it\'s time for a movie like this to triumph once again.While the movie serves as a great w ...
# 1000

# %%
# Creating a DataFrame
reviews_df = pd.DataFrame(dune_Part2_reviews, columns=['reviews'])
reviews_df
# Out:
#                                                reviews
# 0    Had the pleasure to watch this film in an earl...
# 1    If you liked or loved the first one, the same ...
# 2    Dune Part 2 is an epic movie; slickly made, an...
# 3    This is the kind of movie that is impossible t...
# 4    Like the first part, the second part is visual...
# ..                                                 ...
# 995  This was a perfect sequel to Denis' part one. ...
# 996  I just got out of an early access showing and ...
# 997  We have waited many, many years for a movie of...
# 998  This movie has the same problems as part one. ...
# 999  Saw an early screening of this film at the Til...
#
# [1000 rows x 1 columns]

# %%
# Saving to the CSV file
reviews_df.to_csv('dune_Part2_reviews.csv', index=False)
print(' Reviews are collected successfully ')
# Out:
#  Reviews are collected successfully

# %% [markdown]
# # Question 2 (15 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write code for each of the sub parts with proper comments.
#importing all the required modules
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import string
import re


# Download NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
data_url="/content/dune_Part2_reviews.csv"
df = pd.read_table(data_url,names=['text'])
df
# Out:
#                                                    text
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one, the same ...
# 3     Dune Part 2 is an epic movie; slickly made, an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis' part one. ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many, many years for a movie of...
# 999   This movie has the same problems as part one. ...
# 1000  Saw an early screening of this film at the Til...
#
# [1001 rows x 1 columns]

# %%
#1: Remove Noise like special characters and punctuations
def remove_noise(text):
    clean_text = re.sub('[^a-zA-Z0-9]', ' ', text)
    return clean_text
df['clean_text'] = df['text'].apply(remove_noise)
# Printing data frame after noise
print("\nData Frame:")
df
# Out:
# Data Frame:
#                                                    text  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one, the same ...
# 3     Dune Part 2 is an epic movie; slickly made, an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis' part one. ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many, many years for a movie of...
# 999   This movie has the same problems as part one. ...
# 1000  Saw an early screening of this film at the Til...
#
#                                              clean_text
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one  the same ...
# 3     Dune Part 2 is an epic movie  slickly made  an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis  part one  ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many  many years for a movie of...
# 999   This movie has the same problems as part one  ...
# 1000  Saw an early screening of this film at the Til...
#
# [1001 rows x 2 columns]

# %%
#2:- Remove Numbers
#creating remove_number function
def remove_numbers(text):
    clean_text = re.sub(r'\d+', '', text)
    return clean_text
df['clean_text_without_numbers'] = df['clean_text'].apply(remove_numbers)
print("\nData Frame:")
df
# Out:
# Data Frame:
#                                                    text  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one, the same ...
# 3     Dune Part 2 is an epic movie; slickly made, an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis' part one. ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many, many years for a movie of...
# 999   This movie has the same problems as part one. ...
# 1000  Saw an early screening of this film at the Til...
#
#                                              clean_text  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one  the same ...
# 3     Dune Part 2 is an epic movie  slickly made  an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis  part one  ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many  many years for a movie of...
# 999   This movie has the same problems as part one  ...
# 1000  Saw an early screening of this film at the Til...
#
#                              clean_text_without_numbers
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one  the same ...
# 3     Dune Part  is an epic movie  slickly made  and...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis  part one  ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many  many years for a movie of...
# 999   This movie has the same problems as part one  ...
# 1000  Saw an early screening of this film at the Til...
#
# [1001 rows x 3 columns]

# %%
# 3: Remove stopwords by using the stopwords List
#creating remove_stopwords function
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    words = nltk.word_tokenize(text)
    filter_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filter_words)
df['clean_text_without_stopwords'] = df['clean_text_without_numbers'].apply(remove_stopwords)
print("\nData Frame after removing stopwords without lowercase:")
df
# Out:
# Data Frame after removing stopwords without lowercase:
#                                                    text  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one, the same ...
# 3     Dune Part 2 is an epic movie; slickly made, an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis' part one. ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many, many years for a movie of...
# 999   This movie has the same problems as part one. ...
# 1000  Saw an early screening of this film at the Til...
#
#                                              clean_text  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one  the same ...
# 3     Dune Part 2 is an epic movie  slickly made  an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis  part one  ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many  many years for a movie of...
# 999   This movie has the same problems as part one  ...
# 1000  Saw an early screening of this film at the Til...
#
#                              clean_text_without_numbers  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one  the same ...
# 3     Dune Part  is an epic movie  slickly made  and...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis  part one  ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many  many years for a movie of...
# 999   This movie has the same problems as part one  ...
# 1000  Saw an early screening of this film at the Til...
#
#                            clean_text_without_stopwords
# 0                                               reviews
# 1     pleasure watch film early screening completely...
# 2     liked loved first one apply one Personally lov...
# 3     Dune Part epic movie slickly made visually stu...
# 4     kind movie impossible justice talking kind exp...
# ...                                                 ...
# 996   perfect sequel Denis part one accomplished mai...
# 997   got early access showing absolutely incredible...
# 998   waited many many years movie caliber years old...
# 999   movie problems part one editing terrible Scene...
# 1000  Saw early screening film Tilton Square Theatre...
#
# [1001 rows x 4 columns]

# %%
# 4: Lowercase all texts
df['clean_text_lowercase'] = df['clean_text_without_stopwords'].apply(lambda x: x.lower())
print("\nData Frame after converting texts to lowercase:")
df
# Out:
# Data Frame after converting texts to lowercase:
#                                                    text  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one, the same ...
# 3     Dune Part 2 is an epic movie; slickly made, an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis' part one. ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many, many years for a movie of...
# 999   This movie has the same problems as part one. ...
# 1000  Saw an early screening of this film at the Til...
#
#                                              clean_text  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one  the same ...
# 3     Dune Part 2 is an epic movie  slickly made  an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis  part one  ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many  many years for a movie of...
# 999   This movie has the same problems as part one  ...
# 1000  Saw an early screening of this film at the Til...
#
#                              clean_text_without_numbers  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one  the same ...
# 3     Dune Part  is an epic movie  slickly made  and...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis  part one  ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many  many years for a movie of...
# 999   This movie has the same problems as part one  ...
# 1000  Saw an early screening of this film at the Til...
#
#                            clean_text_without_stopwords  \
# 0                                               reviews
# 1     pleasure watch film early screening completely...
# 2     liked loved first one apply one Personally lov...
# 3     Dune Part epic movie slickly made visually stu...
# 4     kind movie impossible justice talking kind exp...
# ...                                                 ...
# 996   perfect sequel Denis part one accomplished mai...
# 997   got early access showing absolutely incredible...
# 998   waited many many years movie caliber years old...
# 999   movie problems part one editing terrible Scene...
# 1000  Saw early screening film Tilton Square Theatre...
#
#                                    clean_text_lowercase
# 0                                               reviews
# 1     pleasure watch film early screening completely...
# 2     liked loved first one apply one personally lov...
# 3     dune part epic movie slickly made visually stu...
# 4     kind movie impossible justice talking kind exp...
# ...                                                 ...
# 996   perfect sequel denis part one accomplished mai...
# 997   got early access showing absolutely incredible...
# 998   waited many many years movie caliber years old...
# 999   movie problems part one editing terrible scene...
# 1000  saw early screening film tilton square theatre...
#
# [1001 rows x 5 columns]

# %%
#5. Stemming
stemmer = PorterStemmer()
def apply_stemming(text):
    words = nltk.word_tokenize(text)
    stemmed_words = [stemmer.stem(word) for word in words]
    return ' '.join(stemmed_words)
df['clean_text_stemmed'] = df['clean_text_lowercase'].apply(apply_stemming)
print("\nData Frame after applying stemming:")
df
# Out:
# Data Frame after applying stemming:
#                                                    text  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one, the same ...
# 3     Dune Part 2 is an epic movie; slickly made, an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis' part one. ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many, many years for a movie of...
# 999   This movie has the same problems as part one. ...
# 1000  Saw an early screening of this film at the Til...
#
#                                              clean_text  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one  the same ...
# 3     Dune Part 2 is an epic movie  slickly made  an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis  part one  ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many  many years for a movie of...
# 999   This movie has the same problems as part one  ...
# 1000  Saw an early screening of this film at the Til...
#
#                              clean_text_without_numbers  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one  the same ...
# 3     Dune Part  is an epic movie  slickly made  and...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis  part one  ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many  many years for a movie of...
# 999   This movie has the same problems as part one  ...
# 1000  Saw an early screening of this film at the Til...
#
#                            clean_text_without_stopwords  \
# 0                                               reviews
# 1     pleasure watch film early screening completely...
# 2     liked loved first one apply one Personally lov...
# 3     Dune Part epic movie slickly made visually stu...
# 4     kind movie impossible justice talking kind exp...
# ...                                                 ...
# 996   perfect sequel Denis part one accomplished mai...
# 997   got early access showing absolutely incredible...
# 998   waited many many years movie caliber years old...
# 999   movie problems part one editing terrible Scene...
# 1000  Saw early screening film Tilton Square Theatre...
#
#                                    clean_text_lowercase  \
# 0                                               reviews
# 1     pleasure watch film early screening completely...
# 2     liked loved first one apply one personally lov...
# 3     dune part epic movie slickly made visually stu...
# 4     kind movie impossible justice talking kind exp...
# ...                                                 ...
# 996   perfect sequel denis part one accomplished mai...
# 997   got early access showing absolutely incredible...
# 998   waited many many years movie caliber years old...
# 999   movie problems part one editing terrible scene...
# 1000  saw early screening film tilton square theatre...
#
#                                      clean_text_stemmed
# 0                                                review
# 1     pleasur watch film earli screen complet blown ...
# 2     like love first one appli one person love one ...
# 3     dune part epic movi slickli made visual stun e...
# 4     kind movi imposs justic talk kind experi never...
# ...                                                 ...
# 996   perfect sequel deni part one accomplish main p...
# 997   got earli access show absolut incred see imax ...
# 998   wait mani mani year movi calib year old femal ...
# 999   movi problem part one edit terribl scene conne...
# 1000  saw earli screen film tilton squar theatr new ...
#
# [1001 rows x 6 columns]

# %%
#6. Lemmatization
lemmatizer = WordNetLemmatizer()
def apply_lemmatization(text):
    words = nltk.word_tokenize(text)
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)
df['clean_text_lemmatized'] = df['clean_text_stemmed'].apply(apply_lemmatization)
print("\nData Frame after applying lemmatization:")
df
# Out:
# Data Frame after applying lemmatization:
#                                                    text  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one, the same ...
# 3     Dune Part 2 is an epic movie; slickly made, an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis' part one. ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many, many years for a movie of...
# 999   This movie has the same problems as part one. ...
# 1000  Saw an early screening of this film at the Til...
#
#                                              clean_text  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one  the same ...
# 3     Dune Part 2 is an epic movie  slickly made  an...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis  part one  ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many  many years for a movie of...
# 999   This movie has the same problems as part one  ...
# 1000  Saw an early screening of this film at the Til...
#
#                              clean_text_without_numbers  \
# 0                                               reviews
# 1     Had the pleasure to watch this film in an earl...
# 2     If you liked or loved the first one  the same ...
# 3     Dune Part  is an epic movie  slickly made  and...
# 4     This is the kind of movie that is impossible t...
# ...                                                 ...
# 996   This was a perfect sequel to Denis  part one  ...
# 997   I just got out of an early access showing and ...
# 998   We have waited many  many years for a movie of...
# 999   This movie has the same problems as part one  ...
# 1000  Saw an early screening of this film at the Til...
#
#                            clean_text_without_stopwords  \
# 0                                               reviews
# 1     pleasure watch film early screening completely...
# 2     liked loved first one apply one Personally lov...
# 3     Dune Part epic movie slickly made visually stu...
# 4     kind movie impossible justice talking kind exp...
# ...                                                 ...
# 996   perfect sequel Denis part one accomplished mai...
# 997   got early access showing absolutely incredible...
# 998   waited many many years movie caliber years old...
# 999   movie problems part one editing terrible Scene...
# 1000  Saw early screening film Tilton Square Theatre...
#
#                                    clean_text_lowercase  \
# 0                                               reviews
# 1     pleasure watch film early screening completely...
# 2     liked loved first one apply one personally lov...
# 3     dune part epic movie slickly made visually stu...
# 4     kind movie impossible justice talking kind exp...
# ...                                                 ...
# 996   perfect sequel denis part one accomplished mai...
# 997   got early access showing absolutely incredible...
# 998   waited many many years movie caliber years old...
# 999   movie problems part one editing terrible scene...
# 1000  saw early screening film tilton square theatre...
#
#                                      clean_text_stemmed  \
# 0                                                review
# 1     pleasur watch film earli screen complet blown ...
# 2     like love first one appli one person love one ...
# 3     dune part epic movi slickli made visual stun e...
# 4     kind movi imposs justic talk kind experi never...
# ...                                                 ...
# 996   perfect sequel deni part one accomplish main p...
# 997   got earli access show absolut incred see imax ...
# 998   wait mani mani year movi calib year old femal ...
# 999   movi problem part one edit terribl scene conne...
# 1000  saw earli screen film tilton squar theatr new ...
#
#                                   clean_text_lemmatized
# 0                                                review
# 1     pleasur watch film earli screen complet blown ...
# 2     like love first one appli one person love one ...
# 3     dune part epic movi slickli made visual stun e...
# 4     kind movi imposs justic talk kind experi never...
# ...                                                 ...
# 996   perfect sequel deni part one accomplish main p...
# 997   got earli access show absolut incred see imax ...
# 998   wait mani mani year movi calib year old femal ...
# 999   movi problem part one edit terribl scene conne...
# 1000  saw earli screen film tilton squar theatr new ...
#
# [1001 rows x 7 columns]

# %%
# Saving the clean data to a new CSV file
df.to_csv('clean_data_.csv', index=False)
print("\nCleaned data saved ")
# Out:
# Cleaned data saved

# %% [markdown]
# # Question 3 (15 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Your code here
import pandas as pd
import nltk
from collections import Counter
# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
# Read the data from cleaned_data_.csv
df = pd.read_csv('clean_data_.csv')

# Part 1: Parts of Speech (POS) Tagging
def pos_tagging(text):
    tokens = nltk.word_tokenize(text)
    pos_tags = nltk.pos_tag(tokens)
    return pos_tags
# Iterate through each row and print the POS tagging on a new line
for index, row in df.iterrows():
    pos_tags = pos_tagging(row['clean_text'])
    print(f"POS tagging for row {index + 1}:\n{pos_tags}\n")
    noun_count = verb_count = adj_count = adv_count = 0
    for _, pos in pos_tags:
        if pos.startswith('N'):
            noun_count += 1
        elif pos.startswith('V'):
            verb_count += 1
        elif pos.startswith('JJ'):
            adj_count += 1
        elif pos.startswith('RB'):
            adv_count += 1
    print(f"Total Nouns: {noun_count}")
    print(f"Total Verbs: {verb_count}")
    print(f"Total Adjectives: {adj_count}")
    print(f"Total Adverbs: {adv_count}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Total Adjectives: 21
# Total Adverbs: 13
# POS tagging for row 288:
# [('Had', 'VBD'), ('the', 'DT'), ('pleasure', 'NN'), ('to', 'TO'), ('watch', 'VB'), ('this', 'DT'), ('film', 'NN'), ('in', 'IN'), ('an', 'DT'), ('early', 'JJ'), ('screening', 'NN'), ('and', 'CC'), ('was', 'VBD'), ('completely', 'RB'), ('blown', 'VBN'), ('away', 'RP'), ('Dune', 'NNP'), ('Part', 'NNP'), ('2', 'CD'), ('is', 'VBZ'), ('everything', 'NN'), ('one', 'NN'), ('could', 'MD'), ('ask', 'VB'), ('for', 'IN'), ('from', 'IN'), ('a', 'DT'), ('film', 'NN'), ('of', 'IN'), ('its', 'PRP$'), ('kind', 'NN'), ('As', 'IN'), ('a', 'DT'), ('big', 'JJ'), ('fan', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Game', 'NNP'), ('of', 'IN'), ('Thrones', 'NNP'), ('franchise', 'NN'), ('it', 'PRP'), ('s', 'VBD'), ('been', 'VBN'), ('a', 'DT'), ('long', 'JJ'), ('time', 'NN'), ('since', 'IN'), ('iv', 'NN'), ('e', 'NN'), ('encountered', 'VBD'), ('this', 'DT'), ('level', 'NN'), ('of', 'IN'), ('world', 'NN'), ('building', 'NN'), ('and', 'CC'), ('epicness', 'VB'), ('The', 'DT'), ('plot', 'NN'), ('and', 'CC'), ('story', 'NN'), ('development', 'NN'), ('are', 'VBP'), ('carried', 'VBN'), ('out', 'RP'), ('in', 'IN'), ('an', 'DT'), ('awe', 'NN'), ('inspiring', 'NN'), ('manner', 'NN'), ('throughout', 'IN'), ('the', 'DT'), ('movie', 'NN'), ('progressing', 'NN'), ('at', 'IN'), ('a', 'DT'), ('precise', 'JJ'), ('pace', 'NN'), ('toward', 'IN'), ('a', 'DT'), ('spectacular', 'JJ'), ('climax', 'NN'), ('that', 'WDT'), ('is', 'VBZ'), ('executed', 'VBN'), ('perfectly', 'RB'), ('Denis', 'NNP'), ('Villeneuve', 'NNP'), ('continues', 'VBZ'), ('to', 'TO'), ('prove', 'VB'), ('himself', 'PRP'), ('as', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('promising', 'JJ'), ('filmmakers', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('time', 'NN'), ('and', 'CC'), ('if', 'IN'), ('it', 'PRP'), ('was', 'VBD'), ('up', 'RB'), ('to', 'TO'), ('me', 'PRP'), ('I', 'PRP'), ('would', 'MD'), ('keep', 'VB'), ('him', 'PRP'), ('in', 'IN'), ('these', 'DT'), ('high', 'JJ'), ('budget', 'NN'), ('epic', 'NN'), ('tales', 'NNS'), ('such', 'JJ'), ('as', 'IN'), ('these', 'DT'), ('since', 'IN'), ('there', 'EX'), ('are', 'VBP'), ('very', 'RB'), ('few', 'JJ'), ('directors', 'NNS'), ('working', 'VBG'), ('today', 'NN'), ('that', 'WDT'), ('can', 'MD'), ('tackle', 'VB'), ('this', 'DT'), ('genre', 'NN'), ('as', 'RB'), ('good', 'JJ'), ('as', 'IN'), ('he', 'PRP'), ('does', 'VBZ'), ('The', 'DT'), ('film', 'NN'), ('received', 'VBD'), ('praise', 'NN'), ('from', 'IN'), ('many', 'JJ'), ('great', 'JJ'), ('filmmakers', 'NNS'), ('the', 'DT'), ('most', 'RBS'), ('notable', 'JJ'), ('being', 'VBG'), ('Christopher', 'NNP'), ('Nolan', 'NNP'), ('The', 'DT'), ('Dark', 'NNP'), ('Knight', 'NNP'), ('Trilogy', 'NNP'), ('Oppenheimer', 'NNP'), ('who', 'WP'), ('very', 'RB'), ('accurately', 'RB'), ('compared', 'VBN'), ('Villeneuve', 'NNP'), ('s', 'JJ'), ('achievement', 'NN'), ('in', 'IN'), ('this', 'DT'), ('film', 'NN'), ('to', 'TO'), ('the', 'DT'), ('Empire', 'NNP'), ('Strikes', 'NNP'), ('Back', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('modern', 'JJ'), ('era', 'NN'), ('Would', 'NNP'), ('highly', 'RB'), ('recommend', 'VBP'), ('to', 'TO'), ('re', 'VB'), ('watch', 'VB'), ('the', 'DT'), ('first', 'JJ'), ('movie', 'NN'), ('in', 'IN'), ('order', 'NN'), ('to', 'TO'), ('appreciate', 'VB'), ('the', 'DT'), ('subtleties', 'NNS'), ('and', 'CC'), ('foreshadowing', 'VBG'), ('better', 'JJR'), ('though', 'IN'), ('it', 'PRP'), ('s', 'VBZ'), ('not', 'RB'), ('completely', 'RB'), ('necessary', 'JJ'), ('since', 'IN'), ('the', 'DT'), ('movie', 'NN'), ('is', 'VBZ'), ('pretty', 'JJ'), ('self', 'NN'), ('contained', 'VBD'), ('More', 'RBR'), ('specifically', 'RB'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('prominent', 'JJ'), ('and', 'CC'), ('impressive', 'JJ'), ('strengths', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('movie', 'NN'), ('is', 'VBZ'), ('how', 'WRB'), ('it', 'PRP'), ('stands', 'VBZ'), ('on', 'IN'), ('its', 'PRP$'), ('own', 'JJ'), ('without', 'IN'), ('relying', 'VBG'), ('too', 'RB'), ('heavily', 'RB'), ('on', 'IN'), ('the', 'DT'), ('firs ...
#
# Total Nouns: 208
# Total Verbs: 118
# Total Adjectives: 77
# Total Adverbs: 60
# POS tagging for row 289:
# [('If', 'IN'), ('you', 'PRP'), ('liked', 'VBD'), ('or', 'CC'), ('loved', 'VBD'), ('the', 'DT'), ('first', 'JJ'), ('one', 'CD'), ('the', 'DT'), ('same', 'JJ'), ('will', 'MD'), ('apply', 'VB'), ('for', 'IN'), ('this', 'DT'), ('one', 'CD'), ('Personally', 'NNP'), ('I', 'PRP'), ('loved', 'VBD'), ('this', 'DT'), ('one', 'CD'), ('even', 'RB'), ('more', 'RBR'), ('and', 'CC'), ('I', 'PRP'), ('think', 'VBP'), ('general', 'JJ'), ('audiences', 'NNS'), ('will', 'MD'), ('as', 'RB'), ('well', 'RB'), ('So', 'IN'), ('I', 'PRP'), ('hope', 'VBP'), ('it', 'PRP'), ('does', 'VBZ'), ('well', 'RB'), ('at', 'IN'), ('the', 'DT'), ('box', 'NN'), ('office', 'NN'), ('because', 'IN'), ('I', 'PRP'), ('need', 'VBP'), ('Dune', 'NNP'), ('Messiah', 'NNP'), ('now', 'RB'), ('This', 'DT'), ('is', 'VBZ'), ('everything', 'NN'), ('I', 'PRP'), ('love', 'VBP'), ('about', 'IN'), ('going', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('movies', 'NNS'), ('Also', 'RB'), ('Hans', 'NNPS'), ('Zimmer', 'NNP'), ('For', 'IN'), ('book', 'NN'), ('readers', 'NNS'), ('I', 'PRP'), ('d', 'VBP'), ('say', 'VB'), ('this', 'DT'), ('one', 'CD'), ('takes', 'VBZ'), ('more', 'JJR'), ('liberties', 'NNS'), ('than', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('but', 'CC'), ('they', 'PRP'), ('were', 'VBD'), ('changes', 'NNS'), ('I', 'PRP'), ('liked', 'VBD'), ('some', 'DT'), ('for', 'IN'), ('the', 'DT'), ('better', 'JJR'), ('even', 'RB'), ('For', 'IN'), ('the', 'DT'), ('most', 'JJS'), ('part', 'NN'), ('it', 'PRP'), ('still', 'RB'), ('hits', 'VBZ'), ('the', 'DT'), ('main', 'JJ'), ('beats', 'NNS'), ('from', 'IN'), ('the', 'DT'), ('book', 'NN'), ('with', 'IN'), ('a', 'DT'), ('few', 'JJ'), ('things', 'NNS'), ('altered', 'VBD'), ('The', 'DT'), ('biggest', 'JJS'), ('change', 'NN'), ('being', 'VBG'), ('no', 'DT'), ('time', 'NN'), ('jump', 'NN'), ('Therefore', 'RB'), ('a', 'DT'), ('certain', 'JJ'), ('character', 'NN'), ('doesn', 'NN'), ('t', 'NN'), ('fully', 'RB'), ('appear', 'VBP'), ('in', 'IN'), ('the', 'DT'), ('movie', 'NN'), ('contrary', 'NN'), ('to', 'TO'), ('the', 'DT'), ('book', 'NN'), ('Though', 'IN'), ('they', 'PRP'), ('still', 'RB'), ('use', 'VBP'), ('the', 'DT'), ('character', 'NN'), ('in', 'IN'), ('a', 'DT'), ('different', 'JJ'), ('way', 'NN'), ('that', 'IN'), ('I', 'PRP'), ('liked', 'VBD'), ('personally', 'RB'), ('I', 'PRP'), ('know', 'VBP'), ('it', 'PRP'), ('s', 'VBZ'), ('early', 'RB'), ('in', 'IN'), ('the', 'DT'), ('year', 'NN'), ('but', 'CC'), ('you', 'PRP'), ('can', 'MD'), ('lock', 'VB'), ('some', 'DT'), ('Oscar', 'NNP'), ('nominations', 'NNS'), ('for', 'IN'), ('this', 'DT'), ('movie', 'NN'), ('Best', 'NNP'), ('Picture', 'NN'), ('Best', 'NNP'), ('Director', 'NNP'), ('Best', 'NNP'), ('Adapted', 'NNP'), ('Screenplay', 'NNP'), ('Best', 'NNP'), ('Editing', 'NNP'), ('Best', 'NNP'), ('Cinematography', 'NNP'), ('Best', 'NNP'), ('Score', 'NNP'), ('Best', 'NNP'), ('Sound', 'NNP'), ('Best', 'NNP'), ('Visual', 'NNP'), ('Effects', 'NNPS'), ('Best', 'NNP'), ('Costume', 'NNP'), ('Best', 'NNP'), ('Production', 'NNP'), ('Design', 'NNP'), ('Best', 'NNP'), ('Makeup', 'NNP'), ('and', 'CC'), ('hopefully', 'RB'), ('Rebecca', 'NNP'), ('Ferguson', 'NNP'), ('this', 'DT'), ('time', 'NN'), ('for', 'IN'), ('Best', 'NNP'), ('Supporting', 'NNP'), ('Actress', 'NNP'), ('I', 'PRP'), ('guess', 'VBP'), ('that', 'IN'), ('s', 'VBP'), ('pretty', 'RB'), ('much', 'JJ'), ('every', 'DT'), ('category', 'NN'), ('now', 'RB'), ('that', 'IN'), ('I', 'PRP'), ('ve', 'VBP'), ('typed', 'VBD'), ('it', 'PRP'), ('out', 'RP'), ('lol', 'NN')]
#
# Total Nouns: 66
# Total Verbs: 29
# Total Adjectives: 13
# Total Adverbs: 17
# POS tagging for row 290:
# [('Dune', 'NNP'), ('Part', 'NNP'), ('2', 'CD'), ('is', 'VBZ'), ('an', 'DT'), ('epic', 'JJ'), ('movie', 'NN'), ('slickly', 'NN'), ('made', 'VBD'), ('and', 'CC'), ('visually', 'RB'), ('stunning', 'JJ'), ('But', 'CC'), ('I', 'PRP'), ('had', 'VBD'), ('to', 'TO'), ('explain', 'VB'), ('quite', 'RB'), ('a', 'DT'), ('bit', 'NN'), ('to', 'TO'), ('the', 'DT'), ('friends', 'NNS'), ('around', 'IN'), ('me', 'PRP'), ('who', 'WP'), ('had', 'VBD'), ('not', 'RB'), ('read', 'VBN'), ('the', 'DT'), ('book', 'NN'), ('especially', 'RB'), ('the', 'DT'), ('water', 'NN'), ('of', 'IN'), ('life', 'NN'), ('scene', 'NN'), ('and', 'CC'), ('the', 'DT'), ('final', 'JJ'), ('battle', 'NN'), ('The', 'DT'), ('movie', 'NN'), ('had', 'VBD'), ('almost', 'RB'), ('a', 'DT'), ('3', 'CD'), ('hour', 'NN'), ('run', 'NN'), ('time', 'NN'), ('but', 'CC'), ('it', 'PRP'), ('felt', 'VBD'), ('overlong', 'RB'), ('because', 'IN'), ('Villenue', 'NNP'), ('focuses', 'VBZ'), ('too', 'RB'), ('much', 'JJ'), ('on', 'IN'), ('spectacle', 'NN'), ('on', 'IN'), ('very', 'RB'), ('little', 'JJ'), ('on', 'IN'), ('substance', 'NN'), ('It', 'PRP'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('movie', 'NN'), ('but', 'CC'), ('it', 'PRP'), ('feels', 'VBZ'), ('like', 'IN'), ('it', 'PRP'), ('has', 'VBZ'), ('no', 'DT'), ('soul', 'NN'), ('The', 'DT'), ('emotional', 'JJ'), ('connection', 'NN'), ('between', 'IN'), ('Paul', 'NNP'), ('and', 'CC'), ('Chani', 'NNP'), ('so', 'RB'), ('vital', 'JJ'), ('to', 'TO'), ('the', 'DT'), ('story', 'NN'), ('is', 'VBZ'), ('completely', 'RB'), ('lacking', 'JJ'), ('and', 'CC'), ('unbelievable', 'JJ'), ('The', 'DT'), ('two', 'CD'), ('main', 'JJ'), ('characters', 'NNS'), ('are', 'VBP'), ('good', 'JJ'), ('looking', 'VBG'), ('enough', 'JJ'), ('but', 'CC'), ('has', 'VBZ'), ('absolutely', 'RB'), ('zero', 'VBN'), ('chemistry', 'NN'), ('on', 'IN'), ('screen', 'NN'), ('I', 'PRP'), ('am', 'VBP'), ('certain', 'JJ'), ('Zendaya', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('fine', 'JJ'), ('actress', 'NN'), ('in', 'IN'), ('some', 'DT'), ('things', 'NNS'), ('but', 'CC'), ('she', 'PRP'), ('has', 'VBZ'), ('basically', 'RB'), ('2', 'CD'), ('facial', 'JJ'), ('expressions', 'NNS'), ('here', 'RB'), ('and', 'CC'), ('the', 'DT'), ('one', 'CD'), ('she', 'PRP'), ('uses', 'VBZ'), ('the', 'DT'), ('most', 'RBS'), ('is', 'VBZ'), ('a', 'DT'), ('scowl', 'NN'), ('directed', 'VBN'), ('at', 'IN'), ('Paul', 'NNP'), ('I', 'PRP'), ('found', 'VBD'), ('her', 'PRP'), ('to', 'TO'), ('be', 'VB'), ('the', 'DT'), ('worst', 'JJS'), ('part', 'NN'), ('of', 'IN'), ('this', 'DT'), ('movie', 'NN'), ('The', 'DT'), ('final', 'JJ'), ('fight', 'NN'), ('scene', 'NN'), ('is', 'VBZ'), ('short', 'JJ'), ('choppy', 'JJ'), ('and', 'CC'), ('a', 'DT'), ('mess', 'NN'), ('It', 'PRP'), ('felt', 'VBD'), ('anticlimactic', 'JJ'), ('and', 'CC'), ('unfulfilling', 'VBG'), ('The', 'DT'), ('Harkonens', 'NNPS'), ('are', 'VBP'), ('basically', 'RB'), ('reduced', 'VBN'), ('to', 'TO'), ('bumbling', 'VBG'), ('villainy', 'JJ'), ('almost', 'RB'), ('cartoonish', 'VB'), ('The', 'DT'), ('ending', 'VBG'), ('was', 'VBD'), ('super', 'JJ'), ('abrupt', 'NN'), ('and', 'CC'), ('was', 'VBD'), ('so', 'RB'), ('different', 'JJ'), ('from', 'IN'), ('the', 'DT'), ('book', 'NN'), ('that', 'IN'), ('it', 'PRP'), ('left', 'VBD'), ('me', 'PRP'), ('wondering', 'VBG'), ('what', 'WP'), ('the', 'DT'), ('filmmakers', 'NNS'), ('would', 'MD'), ('do', 'VB'), ('if', 'IN'), ('they', 'PRP'), ('want', 'VBP'), ('to', 'TO'), ('do', 'VB'), ('a', 'DT'), ('sequel', 'NN'), ('I', 'PRP'), ('want', 'VBP'), ('to', 'TO'), ('reiterate', 'VB'), ('that', 'IN'), ('this', 'DT'), ('isn', 'NN'), ('t', 'VBZ'), ('a', 'DT'), ('bad', 'JJ'), ('movie', 'NN'), ('Villenue', 'NNP'), ('is', 'VBZ'), ('great', 'JJ'), ('at', 'IN'), ('creating', 'VBG'), ('a', 'DT'), ('world', 'NN'), ('that', 'WDT'), ('looks', 'VBZ'), ('living', 'NN'), ('and', 'CC'), ('breathing', 'NN'), ('but', 'CC'), ('he', 'PRP'), ('can', 'MD'), ('t', 'VB'), ('give', 'JJ'), ('life', 'NN'), ('to', 'TO'), ('individual', 'JJ'), ('characters', 'NNS'), ('It ...
#
# Total Nouns: 53
# Total Verbs: 50
# Total Adjectives: 28
# Total Adverbs: 17
# POS tagging for row 291:
# [('This', 'DT'), ('is', 'VBZ'), ('the', 'DT'), ('kind', 'NN'), ('of', 'IN'), ('movie', 'NN'), ('that', 'WDT'), ('is', 'VBZ'), ('impossible', 'JJ'), ('to', 'TO'), ('do', 'VB'), ('justice', 'NN'), ('just', 'RB'), ('by', 'IN'), ('talking', 'VBG'), ('about', 'IN'), ('it', 'PRP'), ('It', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('kind', 'NN'), ('of', 'IN'), ('experience', 'NN'), ('you', 'PRP'), ('had', 'VBD'), ('once', 'RB'), ('but', 'CC'), ('you', 'PRP'), ('never', 'RB'), ('thought', 'VBD'), ('you', 'PRP'), ('would', 'MD'), ('get', 'VB'), ('again', 'RB'), ('until', 'IN'), ('this', 'DT'), ('movie', 'NN'), ('proves', 'VBZ'), ('you', 'PRP'), ('WRONG', 'VBP'), ('This', 'DT'), ('movie', 'NN'), ('takes', 'VBZ'), ('the', 'DT'), ('aspects', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('movie', 'NN'), ('and', 'CC'), ('improves', 'VBZ'), ('upon', 'IN'), ('them', 'PRP'), ('in', 'IN'), ('almost', 'RB'), ('every', 'DT'), ('way', 'NN'), ('possible', 'JJ'), ('already', 'RB'), ('writing', 'VBG'), ('itself', 'PRP'), ('into', 'IN'), ('the', 'DT'), ('books', 'NNS'), ('of', 'IN'), ('greatest', 'JJS'), ('sequels', 'NNS'), ('of', 'IN'), ('ALL', 'NNP'), ('TIME', 'NNP'), ('Everything', 'NNP'), ('in', 'IN'), ('this', 'DT'), ('movie', 'NN'), ('was', 'VBD'), ('TOP', 'NNP'), ('notch', 'NN'), ('Dennis', 'NNP'), ('Villeneauve', 'NNP'), ('proves', 'VBZ'), ('why', 'WRB'), ('he', 'PRP'), ('is', 'VBZ'), ('not', 'RB'), ('only', 'RB'), ('a', 'DT'), ('master', 'NN'), ('of', 'IN'), ('Sci', 'NNP'), ('Fi', 'NNP'), ('movies', 'NNS'), ('but', 'CC'), ('just', 'RB'), ('filmmaking', 'NN'), ('in', 'IN'), ('general', 'JJ'), ('This', 'DT'), ('was', 'VBD'), ('a', 'DT'), ('demonstration', 'NN'), ('of', 'IN'), ('power', 'NN'), ('in', 'IN'), ('what', 'WP'), ('you', 'PRP'), ('can', 'MD'), ('achieve', 'VB'), ('with', 'IN'), ('filmmaking', 'VBG'), ('I', 'PRP'), ('beg', 'VBP'), ('you', 'PRP'), ('to', 'TO'), ('watch', 'VB'), ('this', 'DT'), ('on', 'IN'), ('the', 'DT'), ('biggest', 'JJS'), ('and', 'CC'), ('best', 'JJS'), ('screen', 'NN'), ('you', 'PRP'), ('can', 'MD'), ('find', 'VB'), ('This', 'DT'), ('will', 'MD'), ('be', 'VB'), ('an', 'DT'), ('experience', 'NN'), ('that', 'WDT'), ('will', 'MD'), ('stick', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('forever', 'VBP'), ('I', 'PRP'), ('thought', 'VBD'), ('the', 'DT'), ('real', 'JJ'), ('Blockbuster', 'NNP'), ('was', 'VBD'), ('dead', 'JJ'), ('but', 'CC'), ('I', 'PRP'), ('was', 'VBD'), ('wrong', 'JJ'), ('This', 'DT'), ('is', 'VBZ'), ('the', 'DT'), ('cinematic', 'JJ'), ('experience', 'NN'), ('i', 'NN'), ('craved', 'VBD'), ('Now', 'RB'), ('I', 'PRP'), ('am', 'VBP'), ('gon', 'VBG'), ('na', 'TO'), ('watch', 'VB'), ('this', 'DT'), ('movie', 'NN'), ('again', 'RB'), ('and', 'CC'), ('maybe', 'RB'), ('again', 'RB'), ('Then', 'RB'), ('I', 'PRP'), ('am', 'VBP'), ('gon', 'VBG'), ('na', 'TO'), ('read', 'VB'), ('the', 'DT'), ('books', 'NNS')]
#
# Total Nouns: 34
# Total Verbs: 36
# Total Adjectives: 11
# Total Adverbs: 14
# POS tagging for row 292:
# [('Like', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('part', 'NN'), ('the', 'DT'), ('second', 'JJ'), ('part', 'NN'), ('is', 'VBZ'), ('visually', 'RB'), ('stunning', 'JJ'), ('though', 'IN'), ('having', 'VBG'), ('read', 'VB'), ('the', 'DT'), ('book', 'NN'), ('twice', 'RB'), ('I', 'PRP'), ('regret', 'VBP'), ('to', 'TO'), ('say', 'VB'), ('that', 'IN'), ('unlike', 'IN'), ('the', 'DT'), ('David', 'NNP'), ('Lynch', 'NNP'), ('version', 'NN'), ('from', 'IN'), ('the', 'DT'), ('eighties', 'NNS'), ('De', 'NNP'), ('Villeneuve', 'NNP'), ('almost', 'RB'), ('deliberately', 'RB'), ('destresses', 'VBZ'), ('the', 'DT'), ('mystical', 'JJ'), ('mythical', 'JJ'), ('core', 'NN'), ('of', 'IN'), ('the', 'DT'), ('story', 'NN'), ('This', 'DT'), ('makes', 'VBZ'), ('for', 'IN'), ('an', 'DT'), ('impressive', 'JJ'), ('viewing', 'NN'), ('that', 'WDT'), ('somehow', 'NN'), ('left', 'VBD'), ('me', 'PRP'), ('unsatisfied', 'JJ'), ('In', 'IN'), ('De', 'NNP'), ('Villeneuve', 'NNP'), ('s', 'VBD'), ('hands', 'VBZ'), ('the', 'DT'), ('story', 'NN'), ('becomes', 'VBZ'), ('one', 'CD'), ('of', 'IN'), ('political', 'JJ'), ('grandstanding', 'NN'), ('which', 'WDT'), ('is', 'VBZ'), ('but', 'CC'), ('part', 'NN'), ('of', 'IN'), ('what', 'WP'), ('the', 'DT'), ('book', 'NN'), ('is', 'VBZ'), ('about', 'IN'), ('both', 'DT'), ('in', 'IN'), ('relation', 'NN'), ('to', 'TO'), ('the', 'DT'), ('hidden', 'JJ'), ('ways', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Fremen', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('nature', 'NN'), ('and', 'CC'), ('mission', 'NN'), ('of', 'IN'), ('Paul', 'NNP'), ('and', 'CC'), ('his', 'PRP$'), ('mother', 'NN'), ('For', 'IN'), ('example', 'NN'), ('in', 'IN'), ('the', 'DT'), ('second', 'JJ'), ('part', 'NN'), ('those', 'DT'), ('scenes', 'NNS'), ('where', 'WRB'), ('Paul', 'NNP'), ('Atreides', 'NNP'), ('becomes', 'VBZ'), ('the', 'DT'), ('Kwizatz', 'NNP'), ('Haderach', 'NNP'), ('are', 'VBP'), ('rather', 'RB'), ('weak', 'JJ'), ('and', 'CC'), ('not', 'RB'), ('very', 'RB'), ('convincing', 'VBG'), ('Having', 'VBG'), ('left', 'VBN'), ('this', 'DT'), ('essence', 'NN'), ('out', 'IN'), ('of', 'IN'), ('the', 'DT'), ('movies', 'NNS'), ('they', 'PRP'), ('become', 'VBP'), ('a', 'DT'), ('bit', 'NN'), ('of', 'IN'), ('an', 'DT'), ('emptied', 'VBN'), ('out', 'RP'), ('visual', 'JJ'), ('experience', 'NN'), ('A', 'NNP'), ('kind', 'NN'), ('of', 'IN'), ('secular', 'JJ'), ('profane', 'NN'), ('Dune', 'NNP'), ('Still', 'RB'), ('nice', 'RB'), ('but', 'CC'), ('also', 'RB'), ('a', 'DT'), ('bit', 'NN'), ('disappointing', 'JJ')]
#
# Total Nouns: 42
# Total Verbs: 20
# Total Adjectives: 14
# Total Adverbs: 10
# POS tagging for row 293:
# [('This', 'DT'), ('second', 'JJ'), ('part', 'NN'), ('of', 'IN'), ('the', 'DT'), ('movie', 'NN'), ('sets', 'VBZ'), ('the', 'DT'), ('tone', 'NN'), ('much', 'RB'), ('in', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('way', 'NN'), ('as', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('movie', 'NN'), ('Making', 'VBG'), ('the', 'DT'), ('movie', 'NN'), ('feels', 'NNS'), ('like', 'IN'), ('cramming', 'VBG'), ('alot', 'NN'), ('of', 'IN'), ('story', 'NN'), ('and', 'CC'), ('backdrop', 'NN'), ('in', 'IN'), ('a', 'DT'), ('way', 'NN'), ('too', 'RB'), ('small', 'JJ'), ('time', 'NN'), ('frame', 'NN'), ('Which', 'NNP'), ('is', 'VBZ'), ('logical', 'JJ'), ('considering', 'VBG'), ('Dune', 'NNP'), ('spans', 'NNS'), ('several', 'JJ'), ('novels', 'NNS'), ('with', 'IN'), ('a', 'DT'), ('history', 'NN'), ('of', 'IN'), ('15', 'CD'), ('000', 'CD'), ('years', 'NNS'), ('of', 'IN'), ('civilization', 'NN'), ('Villeneuve', 'NNP'), ('however', 'RB'), ('put', 'VBD'), ('more', 'JJR'), ('focus', 'NN'), ('on', 'IN'), ('aesthetics', 'NNS'), ('rather', 'RB'), ('than', 'IN'), ('storytelling', 'VBG'), ('Which', 'NNP'), ('makes', 'VBZ'), ('the', 'DT'), ('movie', 'NN'), ('a', 'DT'), ('bland', 'NN'), ('and', 'CC'), ('confusing', 'VBG'), ('thing', 'NN'), ('to', 'TO'), ('watch', 'VB'), ('The', 'DT'), ('pacing', 'NN'), ('is', 'VBZ'), ('irregular', 'JJ'), ('at', 'IN'), ('some', 'DT'), ('parts', 'NNS'), ('dragging', 'VBG'), ('alot', 'NN'), ('and', 'CC'), ('towards', 'VBZ'), ('the', 'DT'), ('end', 'NN'), ('you', 'PRP'), ('get', 'VBP'), ('the', 'DT'), ('feeling', 'NN'), ('that', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('rapping', 'VBG'), ('it', 'PRP'), ('up', 'RP'), ('in', 'IN'), ('a', 'DT'), ('unsatisfying', 'JJ'), ('speed', 'NN'), ('Especially', 'NNP'), ('for', 'IN'), ('people', 'NNS'), ('who', 'WP'), ('are', 'VBP'), ('not', 'RB'), ('familiair', 'JJ'), ('with', 'IN'), ('the', 'DT'), ('original', 'JJ'), ('material', 'NN'), ('you', 'PRP'), ('don', 'VBP'), ('t', 'JJ'), ('get', 'VB'), ('the', 'DT'), ('sense', 'NN'), ('what', 'WP'), ('the', 'DT'), ('backstories', 'NNS'), ('are', 'VBP'), ('of', 'IN'), ('the', 'DT'), ('characters', 'NNS'), ('and', 'CC'), ('why', 'WRB'), ('they', 'PRP'), ('made', 'VBD'), ('the', 'DT'), ('decisions', 'NNS'), ('they', 'PRP'), ('made', 'VBD'), ('Cramming', 'VBG'), ('a', 'DT'), ('story', 'NN'), ('like', 'IN'), ('Dune', 'NNP'), ('in', 'IN'), ('a', 'DT'), ('two', 'CD'), ('part', 'NN'), ('sets', 'NNS'), ('of', 'IN'), ('films', 'NNS'), ('is', 'VBZ'), ('probably', 'RB'), ('not', 'RB'), ('doing', 'VBG'), ('the', 'DT'), ('story', 'NN'), ('justice', 'NN'), ('should', 'MD'), ('have', 'VB'), ('been', 'VBN'), ('remade', 'VBN'), ('into', 'IN'), ('an', 'DT'), ('tv', 'NN'), ('series', 'NN'), ('to', 'TO'), ('make', 'VB'), ('it', 'PRP'), ('really', 'RB'), ('work', 'VB'), ('therefore', 'RB'), ('the', 'DT'), ('rewatchability', 'NN'), ('of', 'IN'), ('this', 'DT'), ('rendition', 'NN'), ('of', 'IN'), ('Dune', 'NNP'), ('is', 'VBZ'), ('very', 'RB'), ('unlikely', 'JJ')]
#
# Total Nouns: 52
# Total Verbs: 31
# Total Adjectives: 13
# Total Adverbs: 10
# POS tagging for row 294:
# [('A', 'DT'), ('monumental', 'JJ'), ('piece', 'NN'), ('of', 'IN'), ('cinema', 'NN'), ('Paced', 'NNP'), ('to', 'TO'), ('perfection', 'VB'), ('uniquely', 'RB'), ('beautiful', 'JJ'), ('thought', 'VBD'), ('provoking', 'VBG'), ('beyond', 'IN'), ('thrilling', 'VBG'), ('with', 'IN'), ('unbelievable', 'JJ'), ('cinematography', 'NN'), ('and', 'CC'), ('flawless', 'NN'), ('worldbuilding', 'NN'), ('Backed', 'VBD'), ('up', 'RP'), ('by', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('ensemble', 'JJ'), ('performance', 'NN'), ('in', 'IN'), ('a', 'DT'), ('blockbuster', 'NN'), ('since', 'IN'), ('Fellowship', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Ring', 'NNP'), ('An', 'DT'), ('entire', 'JJ'), ('production', 'NN'), ('on', 'IN'), ('their', 'PRP$'), ('A', 'DT'), ('Game', 'NN'), ('it', 'PRP'), ('s', 'VBD'), ('an', 'DT'), ('incredible', 'JJ'), ('technical', 'JJ'), ('achievement', 'NN'), ('Everyone', 'NN'), ('on', 'IN'), ('set', 'NN'), ('was', 'VBD'), ('clearly', 'RB'), ('aware', 'JJ'), ('they', 'PRP'), ('were', 'VBD'), ('working', 'VBG'), ('on', 'IN'), ('something', 'NN'), ('special', 'JJ'), ('Denis', 'NNP'), ('Villeneuve', 'NNP'), ('s', 'VBZ'), ('love', 'VB'), ('for', 'IN'), ('Dune', 'NNP'), ('shines', 'NNS'), ('through', 'IN'), ('every', 'DT'), ('stunning', 'NN'), ('frame', 'NN'), ('Part', 'NNP'), ('1', 'CD'), ('of', 'IN'), ('his', 'PRP$'), ('adaptation', 'NN'), ('was', 'VBD'), ('wonderful', 'JJ'), ('but', 'CC'), ('here', 'RB'), ('he', 'PRP'), ('improves', 'VBZ'), ('on', 'IN'), ('it', 'PRP'), ('in', 'IN'), ('every', 'DT'), ('way', 'NN'), ('It', 'PRP'), ('just', 'RB'), ('doesn', 'VB'), ('t', 'JJ'), ('get', 'VB'), ('better', 'JJR'), ('than', 'IN'), ('this', 'DT')]
#
# Total Nouns: 25
# Total Verbs: 15
# Total Adjectives: 13
# Total Adverbs: 4
# POS tagging for row 295:
# [('This', 'DT'), ('was', 'VBD'), ('a', 'DT'), ('perfect', 'JJ'), ('sequel', 'NN'), ('to', 'TO'), ('Denis', 'NNP'), ('part', 'NN'), ('one', 'CD'), ('It', 'PRP'), ('accomplished', 'VBD'), ('all', 'PDT'), ('the', 'DT'), ('main', 'JJ'), ('plot', 'NN'), ('points', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('book', 'NN'), ('while', 'IN'), ('delivering', 'VBG'), ('stellar', 'JJ'), ('performances', 'NNS'), ('and', 'CC'), ('visuals', 'NNS'), ('that', 'IN'), ('most', 'JJS'), ('films', 'NNS'), ('only', 'RB'), ('dream', 'NN'), ('of', 'IN'), ('having', 'VBG'), ('This', 'DT'), ('film', 'NN'), ('will', 'MD'), ('go', 'VB'), ('down', 'RP'), ('as', 'RB'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('in', 'IN'), ('sci', 'NN'), ('fi', 'JJ'), ('fantasy', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('deserves', 'VBZ'), ('all', 'PDT'), ('the', 'DT'), ('laurels', 'NNS'), ('it', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('gifted', 'VBN'), ('Not', 'RB'), ('in', 'IN'), ('the', 'DT'), ('longest', 'JJS'), ('time', 'NN'), ('has', 'VBZ'), ('a', 'DT'), ('franchise', 'NN'), ('and', 'CC'), ('a', 'DT'), ('singular', 'JJ'), ('movie', 'NN'), ('captivated', 'VBD'), ('me', 'PRP'), ('in', 'IN'), ('such', 'PDT'), ('a', 'DT'), ('way', 'NN'), ('This', 'DT'), ('story', 'NN'), ('these', 'DT'), ('characters', 'NNS'), ('this', 'DT'), ('planet', 'NN'), ('Dune', 'NNP'), ('lives', 'VBZ'), ('rent', 'JJ'), ('free', 'JJ'), ('in', 'IN'), ('my', 'PRP$'), ('mind', 'NN'), ('You', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('doing', 'VBG'), ('yourself', 'PRP'), ('a', 'DT'), ('disservice', 'NN'), ('not', 'RB'), ('seeing', 'VBG'), ('this', 'DT'), ('film', 'NN'), ('in', 'IN'), ('IMAX', 'NNP'), ('as', 'IN'), ('the', 'DT'), ('soundscapes', 'NNS'), ('created', 'VBN'), ('and', 'CC'), ('the', 'DT'), ('soundtrack', 'NN'), ('by', 'IN'), ('Hans', 'NNP'), ('Zimmer', 'NNP'), ('are', 'VBP'), ('so', 'RB'), ('immersive', 'JJ'), ('you', 'PRP'), ('feel', 'VBP'), ('like', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('a', 'DT'), ('part', 'NN'), ('of', 'IN'), ('every', 'DT'), ('scene', 'NN'), ('This', 'DT'), ('movie', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('masterpiece', 'NN'), ('in', 'IN'), ('storytelling', 'VBG'), ('10', 'CD'), ('10', 'CD')]
#
# Total Nouns: 34
# Total Verbs: 20
# Total Adjectives: 11
# Total Adverbs: 5
# POS tagging for row 296:
# [('I', 'PRP'), ('just', 'RB'), ('got', 'VBD'), ('out', 'RB'), ('of', 'IN'), ('an', 'DT'), ('early', 'JJ'), ('access', 'NN'), ('showing', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('was', 'VBD'), ('absolutely', 'RB'), ('incredible', 'JJ'), ('See', 'NNP'), ('for', 'IN'), ('yourself', 'PRP'), ('in', 'IN'), ('IMAX', 'NNP'), ('The', 'DT'), ('characters', 'NNS'), ('acting', 'VBG'), ('screenplay', 'NN'), ('world', 'NN'), ('building', 'VBG'), ('storytelling', 'VBG'), ('score', 'NN'), ('actions', 'NNS'), ('sequences', 'NNS'), ('cinematography', 'NN'), ('and', 'CC'), ('everything', 'NN'), ('in', 'IN'), ('between', 'IN'), ('make', 'NN'), ('for', 'IN'), ('a', 'DT'), ('cinematic', 'JJ'), ('masterpiece', 'NN'), ('Denis', 'NNP'), ('Villeneuve', 'NNP'), ('provides', 'VBZ'), ('a', 'DT'), ('masterclass', 'NN'), ('of', 'IN'), ('filmmaking', 'VBG'), ('The', 'DT'), ('casting', 'NN'), ('continuation', 'NN'), ('was', 'VBD'), ('perfect', 'JJ'), ('all', 'PDT'), ('the', 'DT'), ('way', 'NN'), ('through', 'IN'), ('with', 'IN'), ('great', 'JJ'), ('new', 'JJ'), ('add', 'NN'), ('ons', 'NNS'), ('Timothee', 'NNP'), ('Chalamet', 'NNP'), ('is', 'VBZ'), ('believable', 'JJ'), ('raw', 'JJ'), ('and', 'CC'), ('real', 'JJ'), ('as', 'IN'), ('Paul', 'NNP'), ('Atriedes', 'NNP'), ('He', 'PRP'), ('was', 'VBD'), ('flawless', 'RB'), ('as', 'IN'), ('the', 'DT'), ('lead', 'NN'), ('Zendaya', 'NNP'), ('Rebecca', 'NNP'), ('Ferguson', 'NNP'), ('Javier', 'NNP'), ('Bardem', 'NNP'), ('and', 'CC'), ('Josh', 'NNP'), ('Brolin', 'NNP'), ('are', 'VBP'), ('fantastic', 'JJ'), ('per', 'IN'), ('usual', 'JJ'), ('Stellan', 'NNP'), ('Skarsgard', 'NNP'), ('and', 'CC'), ('Dave', 'NNP'), ('Bautista', 'NNP'), ('continue', 'VBP'), ('their', 'PRP$'), ('evil', 'JJ'), ('Austin', 'NNP'), ('Butler', 'NNP'), ('steals', 'VBZ'), ('the', 'DT'), ('show', 'NN'), ('as', 'IN'), ('Feyd', 'NNP'), ('Rautha', 'NNP'), ('and', 'CC'), ('Florence', 'NNP'), ('Pugh', 'NNP'), ('and', 'CC'), ('Christopher', 'NNP'), ('Walken', 'NNP'), ('are', 'VBP'), ('solid', 'JJ'), ('fresh', 'JJ'), ('casts', 'NNS'), ('Overall', 'VBP'), ('Dune', 'NNP'), ('Part', 'NNP'), ('Two', 'CD'), ('is', 'VBZ'), ('an', 'DT'), ('inspiring', 'VBG'), ('visually', 'RB'), ('stunning', 'VBG'), ('sci', 'NN'), ('fi', 'JJ'), ('spectacle', 'NN'), ('and', 'CC'), ('an', 'DT'), ('incredible', 'JJ'), ('collision', 'NN'), ('of', 'IN'), ('myth', 'JJ'), ('adventure', 'NN'), ('and', 'CC'), ('destiny', 'NN'), ('on', 'IN'), ('a', 'DT'), ('galactic', 'JJ'), ('scale', 'NN'), ('It', 'PRP'), ('s', 'VBZ'), ('a', 'DT'), ('fantastic', 'JJ'), ('piece', 'NN'), ('of', 'IN'), ('filmmaking', 'VBG'), ('rarely', 'RB'), ('seen', 'VBN'), ('in', 'IN'), ('modern', 'JJ'), ('day', 'NN'), ('cinema', 'NN')]
#
# Total Nouns: 59
# Total Verbs: 21
# Total Adjectives: 20
# Total Adverbs: 6
# POS tagging for row 297:
# [('We', 'PRP'), ('have', 'VBP'), ('waited', 'VBN'), ('many', 'JJ'), ('many', 'JJ'), ('years', 'NNS'), ('for', 'IN'), ('a', 'DT'), ('movie', 'NN'), ('of', 'IN'), ('this', 'DT'), ('caliber', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('59', 'CD'), ('years', 'NNS'), ('old', 'JJ'), ('a', 'DT'), ('female', 'JJ'), ('grandmother', 'NN'), ('and', 'CC'), ('retired', 'VBD'), ('this', 'DT'), ('was', 'VBD'), ('THE', 'DT'), ('BEST', 'NNP'), ('MOVIE', 'NNP'), ('I', 'PRP'), ('have', 'VBP'), ('ever', 'RB'), ('seen', 'VBN'), ('I', 'PRP'), ('don', 'VBP'), ('t', 'JJ'), ('tend', 'VBP'), ('to', 'TO'), ('like', 'VB'), ('si', 'JJ'), ('fi', 'NN'), ('movies', 'NNS'), ('so', 'IN'), ('I', 'PRP'), ('went', 'VBD'), ('along', 'RB'), ('with', 'IN'), ('my', 'PRP$'), ('husband', 'NN'), ('as', 'IN'), ('a', 'DT'), ('favor', 'NN'), ('The', 'DT'), ('length', 'NN'), ('of', 'IN'), ('this', 'DT'), ('movie', 'NN'), ('wasn', 'NN'), ('t', 'VBD'), ('even', 'RB'), ('noticed', 'VBN'), ('by', 'IN'), ('us', 'PRP'), ('it', 'PRP'), ('wasn', 'VBD'), ('t', 'RB'), ('long', 'RB'), ('enough', 'RB'), ('to', 'TO'), ('be', 'VB'), ('honest', 'JJS'), ('We', 'PRP'), ('wanted', 'VBD'), ('MORE', 'JJR'), ('It', 'PRP'), ('ended', 'VBD'), ('and', 'CC'), ('we', 'PRP'), ('weren', 'VBP'), ('t', 'JJ'), ('done', 'VBN'), ('yet', 'RB'), ('We', 'PRP'), ('know', 'VBP'), ('how', 'WRB'), ('long', 'JJ'), ('it', 'PRP'), ('takes', 'VBZ'), ('for', 'IN'), ('sequels', 'NNS'), ('to', 'TO'), ('come', 'VB'), ('along', 'RB'), ('so', 'RB'), ('who', 'WP'), ('knows', 'VBZ'), ('if', 'IN'), ('I', 'PRP'), ('ll', 'VBP'), ('still', 'RB'), ('be', 'VB'), ('on', 'IN'), ('the', 'DT'), ('planet', 'NN'), ('to', 'TO'), ('see', 'VB'), ('it', 'PRP'), ('I', 'PRP'), ('hope', 'VBP'), ('I', 'PRP'), ('am', 'VBP'), ('And', 'CC'), ('I', 'PRP'), ('hope', 'VBP'), ('they', 'PRP'), ('can', 'MD'), ('do', 'VB'), ('it', 'PRP'), ('justice', 'VB'), ('The', 'DT'), ('last', 'JJ'), ('time', 'NN'), ('I', 'PRP'), ('remember', 'VBP'), ('a', 'DT'), ('movie', 'NN'), ('being', 'VBG'), ('THIS', 'NNP'), ('good', 'JJ'), ('I', 'PRP'), ('was', 'VBD'), ('in', 'IN'), ('high', 'JJ'), ('school', 'NN'), ('in', 'IN'), ('the', 'DT'), ('80', 'CD'), ('s', 'NNS'), ('DO', 'NNP'), ('NOT', 'NNP'), ('MISS', 'NNP'), ('THE', 'NNP'), ('OPPORTUNITY', 'NNP'), ('TO', 'NNP'), ('SEE', 'NNP'), ('THIS', 'NNP'), ('MOVIE', 'NNP'), ('IN', 'NNP'), ('THE', 'NNP'), ('THEATRE', 'NNP'), ('CRAZY', 'NNP'), ('GOOD', 'NNP')]
#
# Total Nouns: 35
# Total Verbs: 34
# Total Adjectives: 13
# Total Adverbs: 10
# POS tagging for row 298:
# [('This', 'DT'), ('movie', 'NN'), ('has', 'VBZ'), ('the', 'DT'), ('same', 'JJ'), ('problems', 'NNS'), ('as', 'IN'), ('part', 'NN'), ('one', 'CD'), ('The', 'DT'), ('editing', 'NN'), ('in', 'IN'), ('this', 'DT'), ('is', 'VBZ'), ('terrible', 'JJ'), ('Scenes', 'NNS'), ('don', 'VBP'), ('t', 'JJ'), ('connect', 'NN'), ('they', 'PRP'), ('start', 'VBP'), ('an', 'DT'), ('assignment', 'NN'), ('or', 'CC'), ('story', 'NN'), ('branch', 'NN'), ('then', 'RB'), ('immediately', 'RB'), ('cut', 'VBN'), ('to', 'TO'), ('another', 'DT'), ('completely', 'RB'), ('new', 'JJ'), ('set', 'NN'), ('of', 'IN'), ('tasks', 'NNS'), ('and', 'CC'), ('characters', 'NNS'), ('with', 'IN'), ('their', 'PRP$'), ('own', 'JJ'), ('motivations', 'NNS'), ('and', 'CC'), ('interests', 'NNS'), ('No', 'NNP'), ('idea', 'NN'), ('is', 'VBZ'), ('complete', 'JJ'), ('nothing', 'NN'), ('gets', 'VBZ'), ('resolved', 'VBN'), ('and', 'CC'), ('the', 'DT'), ('dialogue', 'NN'), ('is', 'VBZ'), ('horrendous', 'JJ'), ('These', 'DT'), ('movies', 'NNS'), ('can', 'MD'), ('only', 'RB'), ('appeal', 'VB'), ('to', 'TO'), ('the', 'DT'), ('fans', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('books', 'NNS'), ('because', 'IN'), ('the', 'DT'), ('story', 'NN'), ('is', 'VBZ'), ('too', 'RB'), ('disjointed', 'VBN'), ('for', 'IN'), ('any', 'DT'), ('casual', 'JJ'), ('to', 'TO'), ('follow', 'VB'), ('If', 'IN'), ('you', 'PRP'), ('haven', 'VBP'), ('t', 'JJ'), ('read', 'VBP'), ('the', 'DT'), ('books', 'NNS'), ('you', 'PRP'), ('won', 'VBD'), ('t', 'JJ'), ('understand', 'NN'), ('anything', 'NN'), ('that', 'WDT'), ('s', 'VBZ'), ('happening', 'VBG'), ('here', 'RB'), ('What', 'WP'), ('we', 'PRP'), ('have', 'VBP'), ('here', 'RB'), ('is', 'VBZ'), ('a', 'DT'), ('movie', 'NN'), ('that', 'WDT'), ('is', 'VBZ'), ('really', 'RB'), ('pretty', 'JJ'), ('It', 'PRP'), ('maxes', 'VBZ'), ('out', 'RP'), ('in', 'IN'), ('the', 'DT'), ('visuals', 'NNS'), ('category', 'VBP'), ('The', 'DT'), ('sound', 'NN'), ('was', 'VBD'), ('hit', 'VBN'), ('or', 'CC'), ('miss', 'VBN'), ('but', 'CC'), ('the', 'DT'), ('plot', 'NN'), ('pacing', 'NN'), ('and', 'CC'), ('characters', 'NNS'), ('were', 'VBD'), ('all', 'DT'), ('bad', 'JJ'), ('Not', 'RB'), ('a', 'DT'), ('masterpiece', 'NN'), ('Sorry', 'NNP')]
#
# Total Nouns: 33
# Total Verbs: 27
# Total Adjectives: 12
# Total Adverbs: 9
# POS tagging for row 299:
# [('Saw', 'NNP'), ('an', 'DT'), ('early', 'JJ'), ('screening', 'NN'), ('of', 'IN'), ('this', 'DT'), ('film', 'NN'), ('at', 'IN'), ('the', 'DT'), ('Tilton', 'NNP'), ('Square', 'NNP'), ('Theatre', 'NNP'), ('in', 'IN'), ('New', 'NNP'), ('Jersey', 'NNP'), ('and', 'CC'), ('I', 'PRP'), ('was', 'VBD'), ('completely', 'RB'), ('blown', 'VBN'), ('away', 'RB'), ('From', 'IN'), ('the', 'DT'), ('opening', 'NN'), ('scene', 'NN'), ('all', 'PDT'), ('the', 'DT'), ('way', 'NN'), ('until', 'IN'), ('the', 'DT'), ('credits', 'NNS'), ('I', 'PRP'), ('never', 'RB'), ('felt', 'VBD'), ('bored', 'JJ'), ('which', 'WDT'), ('is', 'VBZ'), ('impressive', 'JJ'), ('for', 'IN'), ('a', 'DT'), ('2', 'CD'), ('hour', 'NN'), ('and', 'CC'), ('45', 'CD'), ('minute', 'NN'), ('film', 'NN'), ('I', 'PRP'), ('don', 'VBP'), ('t', 'JJ'), ('want', 'VBP'), ('to', 'TO'), ('write', 'VB'), ('too', 'RB'), ('much', 'JJ'), ('here', 'RB'), ('I', 'PRP'), ('prefer', 'VBP'), ('anyone', 'NN'), ('reading', 'NN'), ('this', 'DT'), ('with', 'IN'), ('the', 'DT'), ('slightest', 'JJS'), ('bit', 'NN'), ('of', 'IN'), ('interest', 'NN'), ('in', 'IN'), ('the', 'DT'), ('film', 'NN'), ('to', 'TO'), ('go', 'VB'), ('see', 'VB'), ('it', 'PRP'), ('immediately', 'RB'), ('It', 'PRP'), ('doesn', 'VBZ'), ('t', 'JJ'), ('release', 'NN'), ('worldwide', 'NN'), ('until', 'IN'), ('March', 'NNP'), ('1st', 'CD'), ('so', 'RB'), ('grab', 'JJ'), ('tickets', 'NNS'), ('and', 'CC'), ('I', 'PRP'), ('would', 'MD'), ('highly', 'RB'), ('recommended', 'VB'), ('you', 'PRP'), ('see', 'VBP'), ('it', 'PRP'), ('in', 'IN'), ('IMAX', 'NNP'), ('if', 'IN'), ('possible', 'JJ'), ('Almost', 'VBP'), ('the', 'DT'), ('entirety', 'NN'), ('of', 'IN'), ('the', 'DT'), ('movie', 'NN'), ('is', 'VBZ'), ('filmed', 'VBN'), ('with', 'IN'), ('IMAX', 'NNP'), ('cameras', 'VBP'), ('This', 'DT'), ('movie', 'NN'), ('is', 'VBZ'), ('an', 'DT'), ('absolute', 'JJ'), ('visual', 'JJ'), ('spectacle', 'NN'), ('probably', 'RB'), ('going', 'VBG'), ('to', 'TO'), ('win', 'VB'), ('a', 'DT'), ('couple', 'NN'), ('Oscar', 'NNP'), ('s', 'NN'), ('for', 'IN'), ('sound', 'NN'), ('editing', 'JJ'), ('picture', 'NN'), ('etc', 'NN'), ('and', 'CC'), ('the', 'DT'), ('fight', 'NN'), ('scenes', 'NNS'), ('are', 'VBP'), ('choreographed', 'VBN'), ('so', 'RB'), ('fantastically', 'RB'), ('Like', 'IN'), ('I', 'PRP'), ('stated', 'VBD'), ('in', 'IN'), ('the', 'DT'), ('beginning', 'NN'), ('see', 'VB'), ('this', 'DT'), ('film', 'NN')]
#
# Total Nouns: 40
# Total Verbs: 24
# Total Adjectives: 12
# Total Adverbs: 11
# POS tagging for row 300:
# [('The', 'DT'), ('biggest', 'JJS'), ('problem', 'NN'), ('with', 'IN'), ('this', 'DT'), ('movie', 'NN'), ('is', 'VBZ'), ('one', 'CD'), ('that', 'WDT'), ('has', 'VBZ'), ('crept', 'VBN'), ('into', 'IN'), ('Hollywood', 'NNP'), ('over', 'IN'), ('the', 'DT'), ('last', 'JJ'), ('decade', 'NN'), ('and', 'CC'), ('no', 'DT'), ('one', 'NN'), ('seems', 'VBZ'), ('to', 'TO'), ('really', 'RB'), ('acknowledge', 'VB'), ('the', 'DT'), ('actors', 'NNS'), ('mumble', 'VBP'), ('their', 'PRP$'), ('lines', 'NNS'), ('in', 'IN'), ('such', 'JJ'), ('low', 'JJ'), ('tones', 'NNS'), ('you', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('turn', 'VB'), ('the', 'DT'), ('volume', 'NN'), ('up', 'RP'), ('full', 'JJ'), ('blast', 'NN'), ('then', 'RB'), ('when', 'WRB'), ('the', 'DT'), ('character', 'NN'), ('yells', 'VBZ'), ('the', 'DT'), ('audience', 'NN'), ('feels', 'VBZ'), ('the', 'DT'), ('actor', 'NN'), ('is', 'VBZ'), ('more', 'RBR'), ('powerful', 'JJ'), ('then', 'RB'), ('he', 'PRP'), ('she', 'PRP'), ('really', 'RB'), ('is', 'VBZ'), ('but', 'CC'), ('in', 'IN'), ('reality', 'NN'), ('they', 'PRP'), ('are', 'VBP'), ('boring', 'VBG'), ('and', 'CC'), ('wooden', 'JJ'), ('Not', 'RB'), ('to', 'TO'), ('mention', 'VB'), ('your', 'PRP$'), ('ears', 'NNS'), ('fall', 'VBP'), ('off', 'RP'), ('when', 'WRB'), ('their', 'PRP$'), ('is', 'VBZ'), ('a', 'DT'), ('sudden', 'JJ'), ('explosion', 'NN'), ('during', 'IN'), ('the', 'DT'), ('mumbling', 'NN'), ('Gone', 'NNP'), ('are', 'VBP'), ('the', 'DT'), ('days', 'NNS'), ('when', 'WRB'), ('actors', 'NNS'), ('were', 'VBD'), ('given', 'VBN'), ('roles', 'NNS'), ('based', 'VBN'), ('on', 'IN'), ('talent', 'NN'), ('and', 'CC'), ('could', 'MD'), ('actually', 'RB'), ('talk', 'VB'), ('in', 'IN'), ('a', 'DT'), ('normal', 'JJ'), ('clear', 'JJ'), ('tone', 'NN'), ('like', 'IN'), ('George', 'NNP'), ('Clooney', 'NNP'), ('Overall', 'NNP'), ('the', 'DT'), ('movie', 'NN'), ('itself', 'PRP'), ('looks', 'VBZ'), ('amazing', 'JJ'), ('and', 'CC'), ('helps', 'VBZ'), ('people', 'NNS'), ('overlook', 'VBP'), ('the', 'DT'), ('boring', 'NN'), ('as', 'IN'), ('crap', 'NN'), ('first', 'RB'), ('2', 'CD'), ('hours', 'NNS'), ('All', 'PDT'), ('the', 'DT'), ('high', 'JJ'), ('ratings', 'NNS'), ('and', 'CC'), ('reviews', 'NNS'), ('on', 'IN'), ('here', 'RB'), ('are', 'VBP'), ('fans', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('book', 'NN'), ('and', 'CC'), ('fans', 'NNS'), ('of', 'IN'), ('visuals', 'NNS'), ('but', 'CC'), ('clearly', 'RB'), ('don', 'JJ'), ('t', 'NN'), ('go', 'VBP'), ('to', 'TO'), ('movies', 'NNS'), ('to', 'TO'), ('be', 'VB'), ('entertained', 'VBN'), ('Between', 'NNP'), ('the', 'DT'), ('acting', 'NN'), ('of', 'IN'), ('Zendaya', 'NNP'), ('Dave', 'NNP'), ('Bautista', 'NNP'), ('Austin', 'NNP'), ('Butler', 'NNP'), ('and', 'CC'), ('Florence', 'NNP'), ('Pugh', 'NNP'), ('this', 'DT'), ('movie', 'NN'), ('should', 'MD'), ('pick', 'VB'), ('up', 'RP'), ('a', 'DT'), ('few', 'JJ'), ('razzie', 'NN'), ('awards', 'NNS'), ('for', 'IN'), ('bad', 'JJ'), ('acting', 'VBG'), ('assuming', 'VBG'), ('people', 'NNS'), ('realise', 'VBP'), ('an', 'DT'), ('empty', 'JJ'), ('blank', 'JJ'), ('look', 'NN'), ('on', 'IN'), ('your', 'PRP$'), ('face', 'NN'), ('does', 'VBZ'), ('not', 'RB'), ('involve', 'VB'), ('any', 'DT'), ('acting', 'VBG'), ('It', 'PRP'), ('s', 'JJ'), ('time', 'NN'), ('critics', 'NNS'), ('and', 'CC'), ('social', 'JJ'), ('media', 'NNS'), ('reviewers', 'NNS'), ('took', 'VBD'), ('their', 'PRP$'), ('heads', 'NNS'), ('out', 'IN'), ('of', 'IN'), ('their', 'PRP$'), ('lower', 'JJR'), ('back', 'NN'), ('region', 'NN'), ('and', 'CC'), ('stopped', 'VBD'), ('blowing', 'VBG'), ('up', 'RP'), ('average', 'JJ'), ('movies', 'NNS'), ('in', 'IN'), ('an', 'DT'), ('attempt', 'NN'), ('to', 'TO'), ('turn', 'VB'), ('them', 'PRP'), ('into', 'IN'), ('classics', 'NNS'), ('that', 'IN'), ('they', 'PRP'), ('clearly', 'RB'), ('are', 'VBP'), ('not', 'RB')]
#
# Total Nouns: 64
# Total Verbs: 41
# Total Adjectives: 21
# Total Adverbs: 13
# POS tagging for row 301:
# [('Had', 'VBD'), ('the', 'DT'), ('pleasure', 'NN'), ('to', 'TO'), ('watch', 'VB'), ('this', 'DT'), ('film', 'NN'), ('in', 'IN'), ('an', 'DT'), ('early', 'JJ'), ('screening', 'NN'), ('and', 'CC'), ('was', 'VBD'), ('completely', 'RB'), ('blown', 'VBN'), ('away', 'RP'), ('Dune', 'NNP'), ('Part', 'NNP'), ('2', 'CD'), ('is', 'VBZ'), ('everything', 'NN'), ('one', 'NN'), ('could', 'MD'), ('ask', 'VB'), ('for', 'IN'), ('from', 'IN'), ('a', 'DT'), ('film', 'NN'), ('of', 'IN'), ('its', 'PRP$'), ('kind', 'NN'), ('As', 'IN'), ('a', 'DT'), ('big', 'JJ'), ('fan', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Game', 'NNP'), ('of', 'IN'), ('Thrones', 'NNP'), ('franchise', 'NN'), ('it', 'PRP'), ('s', 'VBD'), ('been', 'VBN'), ('a', 'DT'), ('long', 'JJ'), ('time', 'NN'), ('since', 'IN'), ('iv', 'NN'), ('e', 'NN'), ('encountered', 'VBD'), ('this', 'DT'), ('level', 'NN'), ('of', 'IN'), ('world', 'NN'), ('building', 'NN'), ('and', 'CC'), ('epicness', 'VB'), ('The', 'DT'), ('plot', 'NN'), ('and', 'CC'), ('story', 'NN'), ('development', 'NN'), ('are', 'VBP'), ('carried', 'VBN'), ('out', 'RP'), ('in', 'IN'), ('an', 'DT'), ('awe', 'NN'), ('inspiring', 'NN'), ('manner', 'NN'), ('throughout', 'IN'), ('the', 'DT'), ('movie', 'NN'), ('progressing', 'NN'), ('at', 'IN'), ('a', 'DT'), ('precise', 'JJ'), ('pace', 'NN'), ('toward', 'IN'), ('a', 'DT'), ('spectacular', 'JJ'), ('climax', 'NN'), ('that', 'WDT'), ('is', 'VBZ'), ('executed', 'VBN'), ('perfectly', 'RB'), ('Denis', 'NNP'), ('Villeneuve', 'NNP'), ('continues', 'VBZ'), ('to', 'TO'), ('prove', 'VB'), ('himself', 'PRP'), ('as', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('promising', 'JJ'), ('filmmakers', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('time', 'NN'), ('and', 'CC'), ('if', 'IN'), ('it', 'PRP'), ('was', 'VBD'), ('up', 'RB'), ('to', 'TO'), ('me', 'PRP'), ('I', 'PRP'), ('would', 'MD'), ('keep', 'VB'), ('him', 'PRP'), ('in', 'IN'), ('these', 'DT'), ('high', 'JJ'), ('budget', 'NN'), ('epic', 'NN'), ('tales', 'NNS'), ('such', 'JJ'), ('as', 'IN'), ('these', 'DT'), ('since', 'IN'), ('there', 'EX'), ('are', 'VBP'), ('very', 'RB'), ('few', 'JJ'), ('directors', 'NNS'), ('working', 'VBG'), ('today', 'NN'), ('that', 'WDT'), ('can', 'MD'), ('tackle', 'VB'), ('this', 'DT'), ('genre', 'NN'), ('as', 'RB'), ('good', 'JJ'), ('as', 'IN'), ('he', 'PRP'), ('does', 'VBZ'), ('The', 'DT'), ('film', 'NN'), ('received', 'VBD'), ('praise', 'NN'), ('from', 'IN'), ('many', 'JJ'), ('great', 'JJ'), ('filmmakers', 'NNS'), ('the', 'DT'), ('most', 'RBS'), ('notable', 'JJ'), ('being', 'VBG'), ('Christopher', 'NNP'), ('Nolan', 'NNP'), ('The', 'DT'), ('Dark', 'NNP'), ('Knight', 'NNP'), ('Trilogy', 'NNP'), ('Oppenheimer', 'NNP'), ('who', 'WP'), ('very', 'RB'), ('accurately', 'RB'), ('compared', 'VBN'), ('Villeneuve', 'NNP'), ('s', 'JJ'), ('achievement', 'NN'), ('in', 'IN'), ('this', 'DT'), ('film', 'NN'), ('to', 'TO'), ('the', 'DT'), ('Empire', 'NNP'), ('Strikes', 'NNP'), ('Back', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('modern', 'JJ'), ('era', 'NN'), ('Would', 'NNP'), ('highly', 'RB'), ('recommend', 'VBP'), ('to', 'TO'), ('re', 'VB'), ('watch', 'VB'), ('the', 'DT'), ('first', 'JJ'), ('movie', 'NN'), ('in', 'IN'), ('order', 'NN'), ('to', 'TO'), ('appreciate', 'VB'), ('the', 'DT'), ('subtleties', 'NNS'), ('and', 'CC'), ('foreshadowing', 'VBG'), ('better', 'JJR'), ('though', 'IN'), ('it', 'PRP'), ('s', 'VBZ'), ('not', 'RB'), ('completely', 'RB'), ('necessary', 'JJ'), ('since', 'IN'), ('the', 'DT'), ('movie', 'NN'), ('is', 'VBZ'), ('pretty', 'JJ'), ('self', 'NN'), ('contained', 'VBD'), ('More', 'RBR'), ('specifically', 'RB'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('prominent', 'JJ'), ('and', 'CC'), ('impressive', 'JJ'), ('strengths', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('movie', 'NN'), ('is', 'VBZ'), ('how', 'WRB'), ('it', 'PRP'), ('stands', 'VBZ'), ('on', 'IN'), ('its', 'PRP$'), ('own', 'JJ'), ('without', 'IN'), ('relying', 'VBG'), ('too', 'RB'), ('heavily', 'RB'), ('on', 'IN'), ('the', 'DT'), ('firs ...
#
# Total Nouns: 208
# Total Verbs: 118
# Total Adjectives: 77
# Total Adverbs: 60
# POS tagging for row 302:
# [('If', 'IN'), ('you', 'PRP'), ('liked', 'VBD'), ('or', 'CC'), ('loved', 'VBD'), ('the', 'DT'), ('first', 'JJ'), ('one', 'CD'), ('the', 'DT'), ('same', 'JJ'), ('will', 'MD'), ('apply', 'VB'), ('for', 'IN'), ('this', 'DT'), ('one', 'CD'), ('Personally', 'NNP'), ('I', 'PRP'), ('loved', 'VBD'), ('this', 'DT'), ('one', 'CD'), ('even', 'RB'), ('more', 'RBR'), ('and', 'CC'), ('I', 'PRP'), ('think', 'VBP'), ('general', 'JJ'), ('audiences', 'NNS'), ('will', 'MD'), ('as', 'RB'), ('well', 'RB'), ('So', 'IN'), ('I', 'PRP'), ('hope', 'VBP'), ('it', 'PRP'), ('does', 'VBZ'), ('well', 'RB'), ('at', 'IN'), ('the', 'DT'), ('box', 'NN'), ('office', 'NN'), ('because', 'IN'), ('I', 'PRP'), ('need', 'VBP'), ('Dune', 'NNP'), ('Messiah', 'NNP'), ('now', 'RB'), ('This', 'DT'), ('is', 'VBZ'), ('everything', 'NN'), ('I', 'PRP'), ('love', 'VBP'), ('about', 'IN'), ('going', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('movies', 'NNS'), ('Also', 'RB'), ('Hans', 'NNPS'), ('Zimmer', 'NNP'), ('For', 'IN'), ('book', 'NN'), ('readers', 'NNS'), ('I', 'PRP'), ('d', 'VBP'), ('say', 'VB'), ('this', 'DT'), ('one', 'CD'), ('takes', 'VBZ'), ('more', 'JJR'), ('liberties', 'NNS'), ('than', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('but', 'CC'), ('they', 'PRP'), ('were', 'VBD'), ('changes', 'NNS'), ('I', 'PRP'), ('liked', 'VBD'), ('some', 'DT'), ('for', 'IN'), ('the', 'DT'), ('better', 'JJR'), ('even', 'RB'), ('For', 'IN'), ('the', 'DT'), ('most', 'JJS'), ('part', 'NN'), ('it', 'PRP'), ('still', 'RB'), ('hits', 'VBZ'), ('the', 'DT'), ('main', 'JJ'), ('beats', 'NNS'), ('from', 'IN'), ('the', 'DT'), ('book', 'NN'), ('with', 'IN'), ('a', 'DT'), ('few', 'JJ'), ('things', 'NNS'), ('altered', 'VBD'), ('The', 'DT'), ('biggest', 'JJS'), ('change', 'NN'), ('being', 'VBG'), ('no', 'DT'), ('time', 'NN'), ('jump', 'NN'), ('Therefore', 'RB'), ('a', 'DT'), ('certain', 'JJ'), ('character', 'NN'), ('doesn', 'NN'), ('t', 'NN'), ('fully', 'RB'), ('appear', 'VBP'), ('in', 'IN'), ('the', 'DT'), ('movie', 'NN'), ('contrary', 'NN'), ('to', 'TO'), ('the', 'DT'), ('book', 'NN'), ('Though', 'IN'), ('they', 'PRP'), ('still', 'RB'), ('use', 'VBP'), ('the', 'DT'), ('character', 'NN'), ('in', 'IN'), ('a', 'DT'), ('different', 'JJ'), ('way', 'NN'), ('that', 'IN'), ('I', 'PRP'), ('liked', 'VBD'), ('personally', 'RB'), ('I', 'PRP'), ('know', 'VBP'), ('it', 'PRP'), ('s', 'VBZ'), ('early', 'RB'), ('in', 'IN'), ('the', 'DT'), ('year', 'NN'), ('but', 'CC'), ('you', 'PRP'), ('can', 'MD'), ('lock', 'VB'), ('some', 'DT'), ('Oscar', 'NNP'), ('nominations', 'NNS'), ('for', 'IN'), ('this', 'DT'), ('movie', 'NN'), ('Best', 'NNP'), ('Picture', 'NN'), ('Best', 'NNP'), ('Director', 'NNP'), ('Best', 'NNP'), ('Adapted', 'NNP'), ('Screenplay', 'NNP'), ('Best', 'NNP'), ('Editing', 'NNP'), ('Best', 'NNP'), ('Cinematography', 'NNP'), ('Best', 'NNP'), ('Score', 'NNP'), ('Best', 'NNP'), ('Sound', 'NNP'), ('Best', 'NNP'), ('Visual', 'NNP'), ('Effects', 'NNPS'), ('Best', 'NNP'), ('Costume', 'NNP'), ('Best', 'NNP'), ('Production', 'NNP'), ('Design', 'NNP'), ('Best', 'NNP'), ('Makeup', 'NNP'), ('and', 'CC'), ('hopefully', 'RB'), ('Rebecca', 'NNP'), ('Ferguson', 'NNP'), ('this', 'DT'), ('time', 'NN'), ('for', 'IN'), ('Best', 'NNP'), ('Supporting', 'NNP'), ('Actress', 'NNP'), ('I', 'PRP'), ('guess', 'VBP'), ('that', 'IN'), ('s', 'VBP'), ('pretty', 'RB'), ('much', 'JJ'), ('every', 'DT'), ('category', 'NN'), ('now', 'RB'), ('that', 'IN'), ('I', 'PRP'), ('ve', 'VBP'), ('typed', 'VBD'), ('it', 'PRP'), ('out', 'RP'), ('lol', 'NN')]
#
# Total Nouns: 66
# Total Verbs: 29
# Total Adjectives: 13
# Total Adverbs: 17
# POS tagging for row 303:
# ...
#
# Total Nouns: 52
# Total Verbs: 31
# Total Adjectives: 13
# Total Adverbs: 10
# POS tagging for row 996:
# [('A', 'DT'), ('monumental', 'JJ'), ('piece', 'NN'), ('of', 'IN'), ('cinema', 'NN'), ('Paced', 'NNP'), ('to', 'TO'), ('perfection', 'VB'), ('uniquely', 'RB'), ('beautiful', 'JJ'), ('thought', 'VBD'), ('provoking', 'VBG'), ('beyond', 'IN'), ('thrilling', 'VBG'), ('with', 'IN'), ('unbelievable', 'JJ'), ('cinematography', 'NN'), ('and', 'CC'), ('flawless', 'NN'), ('worldbuilding', 'NN'), ('Backed', 'VBD'), ('up', 'RP'), ('by', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('ensemble', 'JJ'), ('performance', 'NN'), ('in', 'IN'), ('a', 'DT'), ('blockbuster', 'NN'), ('since', 'IN'), ('Fellowship', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Ring', 'NNP'), ('An', 'DT'), ('entire', 'JJ'), ('production', 'NN'), ('on', 'IN'), ('their', 'PRP$'), ('A', 'DT'), ('Game', 'NN'), ('it', 'PRP'), ('s', 'VBD'), ('an', 'DT'), ('incredible', 'JJ'), ('technical', 'JJ'), ('achievement', 'NN'), ('Everyone', 'NN'), ('on', 'IN'), ('set', 'NN'), ('was', 'VBD'), ('clearly', 'RB'), ('aware', 'JJ'), ('they', 'PRP'), ('were', 'VBD'), ('working', 'VBG'), ('on', 'IN'), ('something', 'NN'), ('special', 'JJ'), ('Denis', 'NNP'), ('Villeneuve', 'NNP'), ('s', 'VBZ'), ('love', 'VB'), ('for', 'IN'), ('Dune', 'NNP'), ('shines', 'NNS'), ('through', 'IN'), ('every', 'DT'), ('stunning', 'NN'), ('frame', 'NN'), ('Part', 'NNP'), ('1', 'CD'), ('of', 'IN'), ('his', 'PRP$'), ('adaptation', 'NN'), ('was', 'VBD'), ('wonderful', 'JJ'), ('but', 'CC'), ('here', 'RB'), ('he', 'PRP'), ('improves', 'VBZ'), ('on', 'IN'), ('it', 'PRP'), ('in', 'IN'), ('every', 'DT'), ('way', 'NN'), ('It', 'PRP'), ('just', 'RB'), ('doesn', 'VB'), ('t', 'JJ'), ('get', 'VB'), ('better', 'JJR'), ('than', 'IN'), ('this', 'DT')]
#
# Total Nouns: 25
# Total Verbs: 15
# Total Adjectives: 13
# Total Adverbs: 4
# POS tagging for row 997:
# [('This', 'DT'), ('was', 'VBD'), ('a', 'DT'), ('perfect', 'JJ'), ('sequel', 'NN'), ('to', 'TO'), ('Denis', 'NNP'), ('part', 'NN'), ('one', 'CD'), ('It', 'PRP'), ('accomplished', 'VBD'), ('all', 'PDT'), ('the', 'DT'), ('main', 'JJ'), ('plot', 'NN'), ('points', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('book', 'NN'), ('while', 'IN'), ('delivering', 'VBG'), ('stellar', 'JJ'), ('performances', 'NNS'), ('and', 'CC'), ('visuals', 'NNS'), ('that', 'IN'), ('most', 'JJS'), ('films', 'NNS'), ('only', 'RB'), ('dream', 'NN'), ('of', 'IN'), ('having', 'VBG'), ('This', 'DT'), ('film', 'NN'), ('will', 'MD'), ('go', 'VB'), ('down', 'RP'), ('as', 'RB'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('in', 'IN'), ('sci', 'NN'), ('fi', 'JJ'), ('fantasy', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('deserves', 'VBZ'), ('all', 'PDT'), ('the', 'DT'), ('laurels', 'NNS'), ('it', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('gifted', 'VBN'), ('Not', 'RB'), ('in', 'IN'), ('the', 'DT'), ('longest', 'JJS'), ('time', 'NN'), ('has', 'VBZ'), ('a', 'DT'), ('franchise', 'NN'), ('and', 'CC'), ('a', 'DT'), ('singular', 'JJ'), ('movie', 'NN'), ('captivated', 'VBD'), ('me', 'PRP'), ('in', 'IN'), ('such', 'PDT'), ('a', 'DT'), ('way', 'NN'), ('This', 'DT'), ('story', 'NN'), ('these', 'DT'), ('characters', 'NNS'), ('this', 'DT'), ('planet', 'NN'), ('Dune', 'NNP'), ('lives', 'VBZ'), ('rent', 'JJ'), ('free', 'JJ'), ('in', 'IN'), ('my', 'PRP$'), ('mind', 'NN'), ('You', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('doing', 'VBG'), ('yourself', 'PRP'), ('a', 'DT'), ('disservice', 'NN'), ('not', 'RB'), ('seeing', 'VBG'), ('this', 'DT'), ('film', 'NN'), ('in', 'IN'), ('IMAX', 'NNP'), ('as', 'IN'), ('the', 'DT'), ('soundscapes', 'NNS'), ('created', 'VBN'), ('and', 'CC'), ('the', 'DT'), ('soundtrack', 'NN'), ('by', 'IN'), ('Hans', 'NNP'), ('Zimmer', 'NNP'), ('are', 'VBP'), ('so', 'RB'), ('immersive', 'JJ'), ('you', 'PRP'), ('feel', 'VBP'), ('like', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('a', 'DT'), ('part', 'NN'), ('of', 'IN'), ('every', 'DT'), ('scene', 'NN'), ('This', 'DT'), ('movie', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('masterpiece', 'NN'), ('in', 'IN'), ('storytelling', 'VBG'), ('10', 'CD'), ('10', 'CD')]
#
# Total Nouns: 34
# Total Verbs: 20
# Total Adjectives: 11
# Total Adverbs: 5
# POS tagging for row 998:
# [('I', 'PRP'), ('just', 'RB'), ('got', 'VBD'), ('out', 'RB'), ('of', 'IN'), ('an', 'DT'), ('early', 'JJ'), ('access', 'NN'), ('showing', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('was', 'VBD'), ('absolutely', 'RB'), ('incredible', 'JJ'), ('See', 'NNP'), ('for', 'IN'), ('yourself', 'PRP'), ('in', 'IN'), ('IMAX', 'NNP'), ('The', 'DT'), ('characters', 'NNS'), ('acting', 'VBG'), ('screenplay', 'NN'), ('world', 'NN'), ('building', 'VBG'), ('storytelling', 'VBG'), ('score', 'NN'), ('actions', 'NNS'), ('sequences', 'NNS'), ('cinematography', 'NN'), ('and', 'CC'), ('everything', 'NN'), ('in', 'IN'), ('between', 'IN'), ('make', 'NN'), ('for', 'IN'), ('a', 'DT'), ('cinematic', 'JJ'), ('masterpiece', 'NN'), ('Denis', 'NNP'), ('Villeneuve', 'NNP'), ('provides', 'VBZ'), ('a', 'DT'), ('masterclass', 'NN'), ('of', 'IN'), ('filmmaking', 'VBG'), ('The', 'DT'), ('casting', 'NN'), ('continuation', 'NN'), ('was', 'VBD'), ('perfect', 'JJ'), ('all', 'PDT'), ('the', 'DT'), ('way', 'NN'), ('through', 'IN'), ('with', 'IN'), ('great', 'JJ'), ('new', 'JJ'), ('add', 'NN'), ('ons', 'NNS'), ('Timothee', 'NNP'), ('Chalamet', 'NNP'), ('is', 'VBZ'), ('believable', 'JJ'), ('raw', 'JJ'), ('and', 'CC'), ('real', 'JJ'), ('as', 'IN'), ('Paul', 'NNP'), ('Atriedes', 'NNP'), ('He', 'PRP'), ('was', 'VBD'), ('flawless', 'RB'), ('as', 'IN'), ('the', 'DT'), ('lead', 'NN'), ('Zendaya', 'NNP'), ('Rebecca', 'NNP'), ('Ferguson', 'NNP'), ('Javier', 'NNP'), ('Bardem', 'NNP'), ('and', 'CC'), ('Josh', 'NNP'), ('Brolin', 'NNP'), ('are', 'VBP'), ('fantastic', 'JJ'), ('per', 'IN'), ('usual', 'JJ'), ('Stellan', 'NNP'), ('Skarsgard', 'NNP'), ('and', 'CC'), ('Dave', 'NNP'), ('Bautista', 'NNP'), ('continue', 'VBP'), ('their', 'PRP$'), ('evil', 'JJ'), ('Austin', 'NNP'), ('Butler', 'NNP'), ('steals', 'VBZ'), ('the', 'DT'), ('show', 'NN'), ('as', 'IN'), ('Feyd', 'NNP'), ('Rautha', 'NNP'), ('and', 'CC'), ('Florence', 'NNP'), ('Pugh', 'NNP'), ('and', 'CC'), ('Christopher', 'NNP'), ('Walken', 'NNP'), ('are', 'VBP'), ('solid', 'JJ'), ('fresh', 'JJ'), ('casts', 'NNS'), ('Overall', 'VBP'), ('Dune', 'NNP'), ('Part', 'NNP'), ('Two', 'CD'), ('is', 'VBZ'), ('an', 'DT'), ('inspiring', 'VBG'), ('visually', 'RB'), ('stunning', 'VBG'), ('sci', 'NN'), ('fi', 'JJ'), ('spectacle', 'NN'), ('and', 'CC'), ('an', 'DT'), ('incredible', 'JJ'), ('collision', 'NN'), ('of', 'IN'), ('myth', 'JJ'), ('adventure', 'NN'), ('and', 'CC'), ('destiny', 'NN'), ('on', 'IN'), ('a', 'DT'), ('galactic', 'JJ'), ('scale', 'NN'), ('It', 'PRP'), ('s', 'VBZ'), ('a', 'DT'), ('fantastic', 'JJ'), ('piece', 'NN'), ('of', 'IN'), ('filmmaking', 'VBG'), ('rarely', 'RB'), ('seen', 'VBN'), ('in', 'IN'), ('modern', 'JJ'), ('day', 'NN'), ('cinema', 'NN')]
#
# Total Nouns: 59
# Total Verbs: 21
# Total Adjectives: 20
# Total Adverbs: 6
# POS tagging for row 999:
# [('We', 'PRP'), ('have', 'VBP'), ('waited', 'VBN'), ('many', 'JJ'), ('many', 'JJ'), ('years', 'NNS'), ('for', 'IN'), ('a', 'DT'), ('movie', 'NN'), ('of', 'IN'), ('this', 'DT'), ('caliber', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('59', 'CD'), ('years', 'NNS'), ('old', 'JJ'), ('a', 'DT'), ('female', 'JJ'), ('grandmother', 'NN'), ('and', 'CC'), ('retired', 'VBD'), ('this', 'DT'), ('was', 'VBD'), ('THE', 'DT'), ('BEST', 'NNP'), ('MOVIE', 'NNP'), ('I', 'PRP'), ('have', 'VBP'), ('ever', 'RB'), ('seen', 'VBN'), ('I', 'PRP'), ('don', 'VBP'), ('t', 'JJ'), ('tend', 'VBP'), ('to', 'TO'), ('like', 'VB'), ('si', 'JJ'), ('fi', 'NN'), ('movies', 'NNS'), ('so', 'IN'), ('I', 'PRP'), ('went', 'VBD'), ('along', 'RB'), ('with', 'IN'), ('my', 'PRP$'), ('husband', 'NN'), ('as', 'IN'), ('a', 'DT'), ('favor', 'NN'), ('The', 'DT'), ('length', 'NN'), ('of', 'IN'), ('this', 'DT'), ('movie', 'NN'), ('wasn', 'NN'), ('t', 'VBD'), ('even', 'RB'), ('noticed', 'VBN'), ('by', 'IN'), ('us', 'PRP'), ('it', 'PRP'), ('wasn', 'VBD'), ('t', 'RB'), ('long', 'RB'), ('enough', 'RB'), ('to', 'TO'), ('be', 'VB'), ('honest', 'JJS'), ('We', 'PRP'), ('wanted', 'VBD'), ('MORE', 'JJR'), ('It', 'PRP'), ('ended', 'VBD'), ('and', 'CC'), ('we', 'PRP'), ('weren', 'VBP'), ('t', 'JJ'), ('done', 'VBN'), ('yet', 'RB'), ('We', 'PRP'), ('know', 'VBP'), ('how', 'WRB'), ('long', 'JJ'), ('it', 'PRP'), ('takes', 'VBZ'), ('for', 'IN'), ('sequels', 'NNS'), ('to', 'TO'), ('come', 'VB'), ('along', 'RB'), ('so', 'RB'), ('who', 'WP'), ('knows', 'VBZ'), ('if', 'IN'), ('I', 'PRP'), ('ll', 'VBP'), ('still', 'RB'), ('be', 'VB'), ('on', 'IN'), ('the', 'DT'), ('planet', 'NN'), ('to', 'TO'), ('see', 'VB'), ('it', 'PRP'), ('I', 'PRP'), ('hope', 'VBP'), ('I', 'PRP'), ('am', 'VBP'), ('And', 'CC'), ('I', 'PRP'), ('hope', 'VBP'), ('they', 'PRP'), ('can', 'MD'), ('do', 'VB'), ('it', 'PRP'), ('justice', 'VB'), ('The', 'DT'), ('last', 'JJ'), ('time', 'NN'), ('I', 'PRP'), ('remember', 'VBP'), ('a', 'DT'), ('movie', 'NN'), ('being', 'VBG'), ('THIS', 'NNP'), ('good', 'JJ'), ('I', 'PRP'), ('was', 'VBD'), ('in', 'IN'), ('high', 'JJ'), ('school', 'NN'), ('in', 'IN'), ('the', 'DT'), ('80', 'CD'), ('s', 'NNS'), ('DO', 'NNP'), ('NOT', 'NNP'), ('MISS', 'NNP'), ('THE', 'NNP'), ('OPPORTUNITY', 'NNP'), ('TO', 'NNP'), ('SEE', 'NNP'), ('THIS', 'NNP'), ('MOVIE', 'NNP'), ('IN', 'NNP'), ('THE', 'NNP'), ('THEATRE', 'NNP'), ('CRAZY', 'NNP'), ('GOOD', 'NNP')]
#
# Total Nouns: 35
# Total Verbs: 34
# Total Adjectives: 13
# Total Adverbs: 10
# POS tagging for row 1000:
# [('This', 'DT'), ('movie', 'NN'), ('has', 'VBZ'), ('the', 'DT'), ('same', 'JJ'), ('problems', 'NNS'), ('as', 'IN'), ('part', 'NN'), ('one', 'CD'), ('The', 'DT'), ('editing', 'NN'), ('in', 'IN'), ('this', 'DT'), ('is', 'VBZ'), ('terrible', 'JJ'), ('Scenes', 'NNS'), ('don', 'VBP'), ('t', 'JJ'), ('connect', 'NN'), ('they', 'PRP'), ('start', 'VBP'), ('an', 'DT'), ('assignment', 'NN'), ('or', 'CC'), ('story', 'NN'), ('branch', 'NN'), ('then', 'RB'), ('immediately', 'RB'), ('cut', 'VBN'), ('to', 'TO'), ('another', 'DT'), ('completely', 'RB'), ('new', 'JJ'), ('set', 'NN'), ('of', 'IN'), ('tasks', 'NNS'), ('and', 'CC'), ('characters', 'NNS'), ('with', 'IN'), ('their', 'PRP$'), ('own', 'JJ'), ('motivations', 'NNS'), ('and', 'CC'), ('interests', 'NNS'), ('No', 'NNP'), ('idea', 'NN'), ('is', 'VBZ'), ('complete', 'JJ'), ('nothing', 'NN'), ('gets', 'VBZ'), ('resolved', 'VBN'), ('and', 'CC'), ('the', 'DT'), ('dialogue', 'NN'), ('is', 'VBZ'), ('horrendous', 'JJ'), ('These', 'DT'), ('movies', 'NNS'), ('can', 'MD'), ('only', 'RB'), ('appeal', 'VB'), ('to', 'TO'), ('the', 'DT'), ('fans', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('books', 'NNS'), ('because', 'IN'), ('the', 'DT'), ('story', 'NN'), ('is', 'VBZ'), ('too', 'RB'), ('disjointed', 'VBN'), ('for', 'IN'), ('any', 'DT'), ('casual', 'JJ'), ('to', 'TO'), ('follow', 'VB'), ('If', 'IN'), ('you', 'PRP'), ('haven', 'VBP'), ('t', 'JJ'), ('read', 'VBP'), ('the', 'DT'), ('books', 'NNS'), ('you', 'PRP'), ('won', 'VBD'), ('t', 'JJ'), ('understand', 'NN'), ('anything', 'NN'), ('that', 'WDT'), ('s', 'VBZ'), ('happening', 'VBG'), ('here', 'RB'), ('What', 'WP'), ('we', 'PRP'), ('have', 'VBP'), ('here', 'RB'), ('is', 'VBZ'), ('a', 'DT'), ('movie', 'NN'), ('that', 'WDT'), ('is', 'VBZ'), ('really', 'RB'), ('pretty', 'JJ'), ('It', 'PRP'), ('maxes', 'VBZ'), ('out', 'RP'), ('in', 'IN'), ('the', 'DT'), ('visuals', 'NNS'), ('category', 'VBP'), ('The', 'DT'), ('sound', 'NN'), ('was', 'VBD'), ('hit', 'VBN'), ('or', 'CC'), ('miss', 'VBN'), ('but', 'CC'), ('the', 'DT'), ('plot', 'NN'), ('pacing', 'NN'), ('and', 'CC'), ('characters', 'NNS'), ('were', 'VBD'), ('all', 'DT'), ('bad', 'JJ'), ('Not', 'RB'), ('a', 'DT'), ('masterpiece', 'NN'), ('Sorry', 'NNP')]
#
# Total Nouns: 33
# Total Verbs: 27
# Total Adjectives: 12
# Total Adverbs: 9
# POS tagging for row 1001:
# [('Saw', 'NNP'), ('an', 'DT'), ('early', 'JJ'), ('screening', 'NN'), ('of', 'IN'), ('this', 'DT'), ('film', 'NN'), ('at', 'IN'), ('the', 'DT'), ('Tilton', 'NNP'), ('Square', 'NNP'), ('Theatre', 'NNP'), ('in', 'IN'), ('New', 'NNP'), ('Jersey', 'NNP'), ('and', 'CC'), ('I', 'PRP'), ('was', 'VBD'), ('completely', 'RB'), ('blown', 'VBN'), ('away', 'RB'), ('From', 'IN'), ('the', 'DT'), ('opening', 'NN'), ('scene', 'NN'), ('all', 'PDT'), ('the', 'DT'), ('way', 'NN'), ('until', 'IN'), ('the', 'DT'), ('credits', 'NNS'), ('I', 'PRP'), ('never', 'RB'), ('felt', 'VBD'), ('bored', 'JJ'), ('which', 'WDT'), ('is', 'VBZ'), ('impressive', 'JJ'), ('for', 'IN'), ('a', 'DT'), ('2', 'CD'), ('hour', 'NN'), ('and', 'CC'), ('45', 'CD'), ('minute', 'NN'), ('film', 'NN'), ('I', 'PRP'), ('don', 'VBP'), ('t', 'JJ'), ('want', 'VBP'), ('to', 'TO'), ('write', 'VB'), ('too', 'RB'), ('much', 'JJ'), ('here', 'RB'), ('I', 'PRP'), ('prefer', 'VBP'), ('anyone', 'NN'), ('reading', 'NN'), ('this', 'DT'), ('with', 'IN'), ('the', 'DT'), ('slightest', 'JJS'), ('bit', 'NN'), ('of', 'IN'), ('interest', 'NN'), ('in', 'IN'), ('the', 'DT'), ('film', 'NN'), ('to', 'TO'), ('go', 'VB'), ('see', 'VB'), ('it', 'PRP'), ('immediately', 'RB'), ('It', 'PRP'), ('doesn', 'VBZ'), ('t', 'JJ'), ('release', 'NN'), ('worldwide', 'NN'), ('until', 'IN'), ('March', 'NNP'), ('1st', 'CD'), ('so', 'RB'), ('grab', 'JJ'), ('tickets', 'NNS'), ('and', 'CC'), ('I', 'PRP'), ('would', 'MD'), ('highly', 'RB'), ('recommended', 'VB'), ('you', 'PRP'), ('see', 'VBP'), ('it', 'PRP'), ('in', 'IN'), ('IMAX', 'NNP'), ('if', 'IN'), ('possible', 'JJ'), ('Almost', 'VBP'), ('the', 'DT'), ('entirety', 'NN'), ('of', 'IN'), ('the', 'DT'), ('movie', 'NN'), ('is', 'VBZ'), ('filmed', 'VBN'), ('with', 'IN'), ('IMAX', 'NNP'), ('cameras', 'VBP'), ('This', 'DT'), ('movie', 'NN'), ('is', 'VBZ'), ('an', 'DT'), ('absolute', 'JJ'), ('visual', 'JJ'), ('spectacle', 'NN'), ('probably', 'RB'), ('going', 'VBG'), ('to', 'TO'), ('win', 'VB'), ('a', 'DT'), ('couple', 'NN'), ('Oscar', 'NNP'), ('s', 'NN'), ('for', 'IN'), ('sound', 'NN'), ('editing', 'JJ'), ('picture', 'NN'), ('etc', 'NN'), ('and', 'CC'), ('the', 'DT'), ('fight', 'NN'), ('scenes', 'NNS'), ('are', 'VBP'), ('choreographed', 'VBN'), ('so', 'RB'), ('fantastically', 'RB'), ('Like', 'IN'), ('I', 'PRP'), ('stated', 'VBD'), ('in', 'IN'), ('the', 'DT'), ('beginning', 'NN'), ('see', 'VB'), ('this', 'DT'), ('film', 'NN')]
#
# Total Nouns: 40
# Total Verbs: 24
# Total Adjectives: 12
# Total Adverbs: 11

# %%
# Install the required modules
# !pip install benepar
# !pip install tensorflow
# !pip install tensorflow==2.8.0

# Downloading the required models
import benepar
import spacy.cli
benepar.download('benepar_en3')
spacy.cli.download("en_core_web_sm")

# Importing the libraries
import sys
import spacy
from spacy import displacy
parser = benepar.Parser("benepar_en3")
nlp = spacy.load('en_core_web_sm')
options = {'compact': True, 'font': 'Arial black', 'distance': 100}
# Parsing 3rd sentence in clean_text
try:
    tree = parser.parse(df['clean_text'][3])
    print("Constituency Parsing Tree:")
    print(tree)
except Exception as e:
    print(f"Error in constituency parsing: {e}")

# Dependency Parsing
doc = nlp(df['clean_text'][3])
print("Dependency Parsing Tree (Displayed Below):")
displacy.render(doc, style='dep', options=options, jupyter=True)
# Out:
# Requirement already satisfied: benepar in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: nltk>=3.2 in /usr/local/lib/python3.11/dist-packages (from benepar) (3.9.1)
# Requirement already satisfied: spacy>=2.0.9 in /usr/local/lib/python3.11/dist-packages (from benepar) (3.7.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from benepar) (2.5.1+cu124)
# Requirement already satisfied: torch-struct>=0.5 in /usr/local/lib/python3.11/dist-packages (from benepar) (0.5)
# Requirement already satisfied: tokenizers>=0.9.4 in /usr/local/lib/python3.11/dist-packages (from benepar) (0.21.0)
# Requirement already satisfied: transformers>=4.2.2 in /usr/local/lib/python3.11/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (4.48.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from benepar) (4.25.6)
# Requirement already satisfied: sentencepiece>=0.1.91 in /usr/local/lib/python3.11/dist-packages (from benepar) (0.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2->benepar) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2->benepar) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2->benepar) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2->benepar) (4.67.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (0.15.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (1.26.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.9.4->benepar) (0.28.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.6.0->benepar) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.2.2->transformers[tokenizers,torch]>=4.2.2->benepar) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.2.2->transformers[tokenizers,torch]>=4.2.2->benepar) (0.5.2)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (1.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.26.0->transformers[tokenizers,torch]>=4.2.2->benepar) (5.9.5)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=2.0.9->benepar) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.9->benepar) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.9->benepar) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.0.9->benepar) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.0.9->benepar) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=2.0.9->benepar) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=2.0.9->benepar) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy>=2.0.9->benepar) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=2.0.9->benepar) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=2.0.9->benepar) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (0.1.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.8.0 (from versions: 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.0.post1, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0)
# ERROR: No matching distribution found for tensorflow==2.8.0
# [nltk_data] Downloading package benepar_en3 to /root/nltk_data...
# [nltk_data]   Package benepar_en3 is already up-to-date!
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# /usr/local/lib/python3.11/dist-packages/benepar/parse_chart.py:169: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# /usr/local/lib/python3.11/dist-packages/torch/distributions/distribution.py:56: UserWarning: <class 'torch_struct.distributions.TreeCRF'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(
# Constituency Parsing Tree:
# (TOP
#   (S
#     (S
#       (NP (NNP Dune) (NNP Part) (CD 2))
#       (VP
#         (VBZ is)
#         (NP
#           (NP (DT an) (JJ epic) (NN movie))
#           (VP
#             (VP (ADVP (RB slickly)) (VBN made))
#             (CC and)
#             (ADJP (RB visually) (JJ stunning))))))
#     (CC But)
#     (S
#       (S
#         (NP (PRP I))
#         (VP
#           (VBD had)
#           (S
#             (VP
#               (TO to)
#               (VP
#                 (VB explain)
#                 (NP (RB quite) (DT a) (NN bit))
#                 (PP
#                   (IN to)
#                   (NP
#                     (NP
#                       (NP
#                         (NP (DT the) (NNS friends))
#                         (PP (IN around) (NP (PRP me))))
#                       (SBAR
#                         (WHNP (WP who))
#                         (S
#                           (VP
#                             (VBD had)
#                             (RB not)
#                             (VP
#                               (VP (VBN read) (NP (DT the) (NN book)))
#                               (ADVP (RB especially))
#                               (NP
#                                 (NP
#                                   (DT the)
#                                   (NML
#                                     (NML (NN water))
#                                     (PP (IN of) (NP (NN life))))
#                                   (NN scene))
#                                 (CC and)
#                                 (NP (DT the) (JJ final) (NN battle))))))))
#                     (NP (DT The) (NN movie))
#                     (VP
#                       (VP
#                         (VBD had)
#                         (NP
#                           (RB almost)
#                           (DT a)
#                           (NML (CD 3) (NN hour))
#                           (NN run)
#                           (NN time)))
#                       (CC but)
#                       (S
#                         (NP (PRP it))
#                         (VP
#                           (VBD felt)
#                           (ADJP (JJ overlong))
#                           (SBAR
#                             (IN because)
#                             (S
#                               (NP (NNP Villenue))
#                               (VP
#                                 (VP
#                                   (VBZ focuses)
#                                   (NP (ADJP (RB too) (JJ much)))
#                                   (PP
#                                     (PP (IN on) (NP (NN spectacle)))
#                                     (PP
#                                       (IN on)
#                                       (NP
#                                         (ADJP (RB very) (JJ little))
#                                         (PP
#                                           (IN on)
#                                           (NP (NN substance)))))))
#                                 (S
#                                   (NP (PRP It))
#                                   (VP
#                                     (VP
#                                       (VBZ is)
#                                       (NP
#                                         (DT a)
#                                         (JJ beautiful)
#                                         (NN movie)))
#                                     (CC but)
#                                     (S
#                                       (NP (PRP it))
#                                       (VP
#                                         (VBZ feels)
#                                         (SBAR
#                                           (IN like)
#                                           (S
#                                             (NP (PRP it))
#                                             (VP
#                                               (VBZ has)
#                                               (NP
#                                                 (NP
#                                                   (NP
#                                                     (DT no)
#                                                     (NN soul))
#                                                   (NP
#                                                     (NP
#                                                       (DT The)
#                                                       (JJ emotional)
#                                                       (NN connection))
#                                                     (PP
#                                                       (PP
#                                                         (IN between)
#                                                         (NP
#                                                           (NNP Paul)
#                                                           (CC and)
#                                                           (NNP Chani)))
#                                                       (ADJP
#                                                         (RB so)
#                                                         (JJ vital)
#                                                         (PP
#                                                           (IN to)
#                                                           (NP
#                                                             (DT the)
#                                                             (NN
#                                                               story)))))))
#                                                 (VP
#                                                   (VBZ is)
#                                                   (ADJP
#                                                     (ADJP
#                                                       (ADJP
#                                                         (RB
#                                                           completely)
#                                                         (JJ lacking))
#                                                       (CC and)
#                                                       (JJ
#                                                         unbelievable))
#                                                     (S
#                                                       (DT The)
#                                                       (CD two)
#                                                       (JJ main)
#                                                       (NNS
#                                                         characters)
#                                                       (PP
#                                                         (. are)
#                                                         (ADJP
#                                                           (JJ good))
#                                                         (VBG looking)
#                                                         (. enough))
#                                                       (CC but)
#                                                       (VP
#                                                         (VBZ has)
#                                                         (NP
#                                                           (NP
#                                                             (RB
#                                                               absolutely)
#                                                             (JJ zero)
#                                                             (NN
#                                                               chemistry))
#                                                           (PP
#                                                             (IN on)
#                                                             (NP
#                                                               (NP
#                                                                 (NN
#                                                                   screen))
#                                                               (NP
#                                                                 (PRP
#                                                                   I))
#                                                               (VP
#                                                                 (VBP
#                                                                   am)
#                                                                 (ADJP
#                                                                   (JJ
#                                                                     certain)
#                                                                   (SBAR
#                                                                     (S
#                                                                       (NNP
#                                                                         Zendaya)
#                                                                       (VP
#                                                                         (VBZ
#                                                                           is)
#                                                                         (NP
#                                                                           (NP
#                                                                             (DT
#                                                                               a)
#                                                                             (JJ
#                                                                               fine)
#                                                                             (NN
#                                                                               actress))
#                                                                           (PP
#                                                                             (PP
#                                                                               (IN
#                                                                                 in)
#                                                                               (NP
#                                                                                 (DT
#                                                                                   some)
#                                                                                 (NNS
#                                                                                   things)))
#                                                                             (CC
#                                                                               but)
#                                                                             (S
#                                                                               (NP
#                                                                                 (PRP
#                                                                                   she))
#                                                                               (VP
#                                                                                 (VP
#                                                                                   (VBZ
#                                                                                     has)
#                                                                                   (ADVP
#                                                                                     (RB
#                                                                                       basically))
#                                                                                   (NP
#                                                                                     (NP
#                                                                                       (CD
#                                                                                         2)
#                                                                                       (JJ
#                                                                                         facial)
#                                                                                       (NNS
#                                                                                         expressions))
#                                                                                     (ADVP
#                                                                                       (RB
#                                                                                         here))))
#                                                                                 (CC
#                                                                                   and)
#                                                                                 (NP
#                                                                                   (NP
#                                                                                     (DT
#                                                                                       the)
#                                                                                     (NN
#                                                                                       one))
#                                                                                   (SBAR
#                                                                                     (S
#                                                                                       (NP
#                                                                                         (PRP
#                                                                                           she))
#                                                                                       (VP
#                                                                                         (VP
#                                                                                           (VBZ
#                                                                                             uses)
#                                                                                           (DT
#                                                                                             the)
#                                                                                           (RBS
#                                                                                             most))
#                                                                                         (VP
#                                                                                           (VBZ
#                                                                                             is)
#                                                                                           (NP
#                                                                                             (NP
#                                                                                               (DT
#                                                                                                 a)
#                                                                                               (NN
#                                                                                                 scowl))
#                                                                                             (VP
#                                                                                               (VBN
#                                                                                                 directed)
#                                                                                               (PP
#                                                                                                 (PP
#                                                                                                   (IN
#                                                                                                     at)
#                                                                                                   (NP
#                                                                                                     (NNP
#                                                                                                       Paul)))
#                                                                                                 (NP
#                                                                                                   (NP
#                                                                                                     (PRP
#                                                                                                       I))
#                                                                                                   (VP
#                                                                                                     (VBD
#                                                                                                       found)
#                                                                                                     (S
#                                                                                                       (NP
#                                                                                                         (PRP
#                                                                                                           her))
#                                                                                                       (S
#                                                                                                         (VP
#                                                                                                           (TO
#                                                                                                             to)
#                                                                                                           (VP
#                                                                                                             (VB
#                                                                                                               be)
#                                                                                                             (NP
#                                                                                                               (NP
#                                                                                                                 (DT
#                                                                                                                   the)
#                                                                                                                 (JJS
#                                                                                                                   worst)
#                                                                                                                 (NN
#                                                                                                                   part))
#                                                                                                               (PP
#                                                                                                                 (PP
#                                                                                                                   (IN
#                                                                                                                     of)
#                                                                                                                   (NP
#                                                                                                                     (DT
#                                                                                                                       this)
#                                                                                                                     (NN
#                                                                                                                       movie)))
#                                                                                                                 (NP
#                                                                                                                   (NP
#                                                                                                                     (DT
#                                                                                                                       The)
#                                                                                                                     (JJ
#                                                                                                                       final)
#                                                                                                                     (NN
#                                                                                                                       fight)
#                                                                                                                     (NN
#                                                                                                                       scene))
#                                                                                                                   (VP
#                                                                                                                     (VP
#                                                                                                                       (VBZ
#                                                                                                                         is)
#                                                                                                                       (ADJP
#                                                                                                                         (JJ
#                                                                                                                           short)
#                                                                                                                         (JJ
#                                                                                                                           choppy)))
#                                                                                                                     (CC
#                                                                                                                       and)
#                                                                                                                     (NP
#                                                                                                                       (NP
#                                                                                                                         (NP
#                                                                                                                           (DT
#                                                                                                                             a)
#                                                                                                                           (NN
#                                                                                                                             mess))
#                                                                                                                         (NP
#                                                                                                                           (PRP
#                                                                                                                             It)))
#                                                                                                                       (VP
#                                                                                                                         (VBD
#                                                                                                                           felt)
#                                                                                                                         (ADJP
#                                                                                                                           (ADJP
#                                                                                                                             (ADJP
#                                                                                                                               (JJ
#                                                                                                                                 anticlimactic))
#                                                                                                                             (CC
#                                                                                                                               and)
#                                                                                                                             (ADJP
#                                                                                                                               (JJ
#                                                                                                                                 unfulfilling)))
#                                                                                                                           (S
#                                                                                                                             (NP
#                                                                                                                               (DT
#                                                                                                                                 The)
#                                                                                                                               (NNPS
#                                                                                                                                 Harkonens))
#                                                                                                                             (VP
#                                                                                                                               (VBP
#                                                                                                                                 are)
#                                                                                                                               (ADVP
#                                                                                                                                 (RB
#                                                                                                                                   basically))
#                                                                                                                               (VP
#                                                                                                                                 (VBN
#                                                                                                                                   reduced)
#                                                                                                                                 (PP
#                                                                                                                                   (IN
#                                                                                                                                     to)
#                                                                                                                                   (NP
#                                                                                                                                     (NP
#                                                                                                                                       (VBG
#                                                                                                                                         bumbling)
#                                                                                                                                       (NN
#                                                                                                                                         villainy))
#                                                                                                                                     (NP
#                                                                                                                                       (ADJP
#                                                                                                                                         (RB
#                                                                                                                                           almost)
#                                                                                                                                         (JJ
#                                                                                                                                           cartoonish))
# ...
#                                                                                                                                                                                               (NNP
#                                                                                                                                                                                                 Villenue))
#                                                                                                                                                                                             (VP
#                                                                                                                                                                                               (VBZ
#                                                                                                                                                                                                 is)
#                                                                                                                                                                                               (ADJP
#                                                                                                                                                                                                 (JJ
#                                                                                                                                                                                                   great)
#                                                                                                                                                                                                 (PP
#                                                                                                                                                                                                   (IN
#                                                                                                                                                                                                     at)
#                                                                                                                                                                                                   (S
#                                                                                                                                                                                                     (VP
#                                                                                                                                                                                                       (VBG
#                                                                                                                                                                                                         creating)
#                                                                                                                                                                                                       (NP
#                                                                                                                                                                                                         (NP
#                                                                                                                                                                                                           (DT
#                                                                                                                                                                                                             a)
#                                                                                                                                                                                                           (NN
#                                                                                                                                                                                                             world))
#                                                                                                                                                                                                         (.
#                                                                                                                                                                                                           that)
#                                                                                                                                                                                                         (S
#                                                                                                                                                                                                           (VP
#                                                                                                                                                                                                             (VBZ
#                                                                                                                                                                                                               looks)
#                                                                                                                                                                                                             (NP
#                                                                                                                                                                                                               (JJ
#                                                                                                                                                                                                                 living)
#                                                                                                                                                                                                               (CC
#                                                                                                                                                                                                                 and)
#                                                                                                                                                                                                               (NN
#                                                                                                                                                                                                                 breathing)))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))
#       (CC but)
#       (S
#         (NP
#           (S
#             (NP
#               (S
#                 (VP
#                   (NP (PRP he))
#                   (VP
#                     (MD can)
#                     (RB t)
#                     (S
#                       (VP
#                         (VB give)
#                         (NP (NN life))
#                         (PP
#                           (IN to)
#                           (NP (JJ individual) (NNS characters))))))))
#               (NP (PRP It)))
#             (VBZ is))
#           (. like)
#           (NP (PRP he)))
#         (VP
#           (MD can)
#           (RB t)
#           (VP
#             (VB see)
#             (NP
#               (NP (DT the) (NNS trees))
#               (PP (IN for) (NP (DT the) (NN forest))))))))))
# Dependency Parsing Tree (Displayed Below):
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="bb04e2b41e834f1d9f7643a993a53387-0" class="displacy" width="27150" height="537.0" direction="ltr" style="max-width: none; height: 537.0px; color: #000000; background: #ffffff; font-family: Arial black; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Dune</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">Part</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">epic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">movie</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="750"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">slickly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">made</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">visually</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">stunning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">But</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">explain</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">quite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">bit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">friends</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2550">around</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">me</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2950">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2950">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">read</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">VERB</tspan>
# </text>
#
# <tex

# %%
# (3) Named Entity Recognition
import en_core_web_sm
# Loading the spaCy English model
nlp=en_core_web_sm.load()
# Named Entity Recognition (NER)
for x in df['clean_text']:
    doc = nlp(x)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    if entities:
        print(entities)
# Out:
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# ...
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]
# [('Hollywood', 'GPE'), ('the last decade', 'DATE'), ('the days', 'DATE'), ('George Clooney Overall', 'PERSON'), ('Zendaya  Dave Bautista  ', 'PERSON'), ('Austin Butler', 'PERSON'), ('Florence Pugh', 'PERSON')]
# [('2', 'CARDINAL'), ('Thrones', 'ORG'), ('Denis Villeneuve', 'PERSON'), ('today', 'DATE'), ('Christopher Nolan', 'PERSON'), ('The Dark Knight Trilogy  ', 'ORG'), ('Oppenheimer', 'ORG'), ('Villeneuve', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('a few years ago', 'DATE'), ('don', 'PERSON'), ('2', 'CARDINAL'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Timoth e Chalamet', 'ORG'), ('Zendaya', 'PERSON'), ('first', 'ORDINAL'), ('Austin Butler', 'PERSON'), ('Rebecca Ferguson', 'PERSON'), ('one', 'CARDINAL'), ('the year', 'DATE'), ('Javier Bardem', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('one', 'CARDINAL'), ('Oscar', 'PERSON'), ('Grammy', 'PERSON'), ('VFX  Production Design  Sound', 'ORG'), ('Denis', 'NORP'), ('1', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('recent decades', 'DATE'), ('Frank Herbert', 'PERSON'), ('many years ago', 'DATE'), ('Award Season  Below', 'PERSON'), ('the Fantasy Sci Fi', 'ORG'), ('recent years', 'DATE'), ('the Academy  ', 'ORG'), ('1', 'CARDINAL'), ('Dune  Messiah', 'PRODUCT'), ('Don', 'PERSON'), ('Fantasy Sci Fi', 'PERSON')]
# [('first', 'ORDINAL'), ('one', 'CARDINAL'), ('Dune Messiah', 'PERSON'), ('Hans Zimmer', 'PERSON'), ('first', 'ORDINAL'), ('the year', 'DATE'), ('Oscar', 'PERSON'), ('Best Picture', 'WORK_OF_ART'), ('Rebecca Ferguson', 'PERSON'), ('Best Supporting Actress', 'ORG')]
# [('2', 'CARDINAL'), ('almost a 3 hour', 'TIME'), ('Villenue', 'GPE'), ('Paul', 'PERSON'), ('two', 'CARDINAL'), ('zero', 'CARDINAL'), ('Zendaya', 'PERSON'), ('2', 'CARDINAL'), ('Paul', 'PERSON'), ('The Harkonens', 'WORK_OF_ART'), ('Villenue', 'GPE')]
# [('first', 'ORDINAL'), ('Dennis Villeneauve', 'PERSON'), ('Sci Fi', 'ORG'), ('Blockbuster', 'PERSON')]
# [('first', 'ORDINAL'), ('second', 'ORDINAL'), ('David Lynch', 'PERSON'), ('De Villeneuve', 'LOC'), ('De Villeneuve', 'LOC'), ('one', 'CARDINAL'), ('Fremen', 'WORK_OF_ART'), ('Paul', 'PERSON'), ('second', 'ORDINAL'), ('Paul Atreides', 'PERSON')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL'), ('Dune', 'PRODUCT'), ('15 000 years', 'DATE'), ('Villeneuve', 'PERSON'), ('Dune', 'PRODUCT'), ('two', 'CARDINAL')]
# [('A Game', 'WORK_OF_ART'), ('Denis Villeneuve', 'PERSON'), ('1', 'CARDINAL')]
# [('Denis', 'NORP'), ('one', 'CARDINAL'), ('sci fi fantasy', 'ORG'), ('Hans Zimmer', 'PERSON'), ('10 10', 'CARDINAL')]
# [('Denis Villeneuve', 'PERSON'), ('Timothee Chalamet', 'PERSON'), ('Paul Atriedes', 'PERSON'), ('Zendaya', 'GPE'), ('Rebecca Ferguson', 'PERSON'), ('Javier Bardem', 'PERSON'), ('Josh Brolin', 'PERSON'), ('Stellan Skarsgard', 'PERSON'), ('Dave Bautista', 'PERSON'), ('Austin Butler', 'PERSON'), ('Feyd Rautha', 'PERSON'), ('Florence Pugh', 'ORG'), ('Christopher Walken', 'PERSON'), ('Two', 'CARDINAL'), ('sci', 'ORG')]
# [('59 years old', 'DATE'), ('80', 'CARDINAL')]
# [('Scenes', 'PRODUCT')]
# [('the Tilton Square Theatre', 'FAC'), ('New Jersey', 'GPE'), ('2 hour and 45 minute', 'TIME'), ('March 1st', 'DATE'), ('Oscar', 'PERSON')]

# %% [markdown]
# # **Following Questions must answer using AI assitance**

# %% [markdown]
# #Question 4 (20 points).

# %% [markdown]
# Q4. (PART-1)
# Web scraping data from the GitHub Marketplace to gather details about popular actions. Using Python, the process begins by sending HTTP requests to multiple pages of the marketplace (1000 products), handling pagination through dynamic page numbers. The key details extracted include the product name, a short description, and the URL.
#
#  The extracted data is stored in a structured CSV format with columns for product name, description, URL, and page number. A time delay is introduced between requests to avoid server overload. ChatGPT can assist by helping with the parsing of HTML, error handling, and generating reports based on the data collected.
#
#  The goal is to complete the scraping within a specified time limit, ensuring that the process is efficient and adheres to GitHub’s usage guidelines.
#
# (PART -2)
#
# 1.   **Preprocess Data**: Clean the text by tokenizing, removing stopwords, and converting to lowercase.
#
# 2. Perform **Data Quality** operations.
#
#
# Preprocessing:
# Preprocessing involves cleaning the text by removing noise such as special characters, HTML tags, and unnecessary whitespace. It also includes tasks like tokenization, stopword removal, and lemmatization to standardize the text for analysis.
#
# Data Quality:
# Data quality checks ensure completeness, consistency, and accuracy by verifying that all required columns are filled and formatted correctly. Additionally, it involves identifying and removing duplicates, handling missing values, and ensuring the data reflects the true content accurately.

# %% [markdown]
# Github MarketPlace page:
# https://github.com/marketplace?type=actions

# %%
import time

# Base URL of GitHub Marketplace (Actions section)
BASE_URL = "https://github.com/marketplace?type=actions&page="

# Headers to mimic a browser request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,/;q=0.8",
    "Referer": "https://www.google.com/",
}

# Initialize list to store data
data = []
page = 0
# Scrape multiple pages (Assuming 20 products per page, we need ~50 pages for 1000 products)
while len(data)<1000:
    page+=1
    url = f"{BASE_URL}{page}"

    response = requests.get(url, headers=headers)
    #print(response.text)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    soup = BeautifulSoup(response.text, "html.parser")

    # Find all product containers

    items = soup.find_all('div', {'data-testid': 'non-featured-item'})
    for item in items:
        try:
            name = item.find('a', class_='marketplace-common-module__marketplace-item-link--jrIHf').text.strip()
            url = "https://github.com" + item.find('a')['href']
            description = item.find('p', class_='text-small').text.strip()
            data.append([name, description, url, page])
        except AttributeError:
            continue

# Save to CSV
df = pd.DataFrame(data, columns=["Product Name", "Description", "URL", "Page Number"])

df.to_csv("github_marketplace_actions.csv", index=False)
print("Scraping completed! Data saved to github_marketplace_actions.csv")
# Out:
# Scraping completed! Data saved to github_marketplace_actions.csv

# %%
#Part2
from nltk.tokenize import word_tokenize
df = pd.read_csv('/content/github_marketplace_actions.csv')

# Data Cleaning
def clean_text(text):
    text = str(text)  # making sure it's a string
    text = re.sub(r"<.*?>", "", text)  # Removing HTML tags
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)  # Removing special characters
    text = text.lower()  # Convert to lowercase
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra spaces
    return text

# Apply text cleaning to Name & Description columns
df["Product Name"] = df["Product Name"].apply(clean_text)
df["Description"] = df["Description"].apply(clean_text)

# Tokenization, Stopword Removal, Lemmatization
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]  # Remove stopwords
    tokens = [lemmatizer.lemmatize(word) for word in tokens]  # Lemmatization
    return " ".join(tokens)

df["Processed Description"] = df["Description"].apply(preprocess_text)

# Data Quality Checks
df.drop_duplicates(inplace=True)  # Remove duplicates
df.dropna(inplace=True)  # Handle missing values

# Save cleaned data
df.to_csv("cleaned_github_marketplace_actions.csv", index=False)

print("Cleaned data saved.")
# Out:
# Cleaned data saved.

# %% [markdown]
# #Question 5 (20 points)
#
# PART 1:
# Web Scrape  tweets from Twitter using the Tweepy API, specifically targeting hashtags related to subtopics (machine learning or artificial intelligence.)
# The extracted data includes the tweet ID, username, and text.
#
# Part 2:
# Perform data cleaning procedures
#
# A final data quality check ensures the completeness and consistency of the dataset. The cleaned data is then saved into a CSV file for further analysis.
#
#
# **Note**
#
# 1.   Follow tutorials provided in canvas to obtain api keys. Use ChatGPT to get the code. Make sure the file is downloaded and saved.
# 2.   Make sure you divide GPT code as shown in tutorials, dont make multiple requestes.

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.11/dist-packages (4.15.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (2.32.3)
# Requirement already satisfied: requests-oauthlib<3,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (2025.1.31)

# %%
import tweepy

# Set your keys and tokens here
api_key =
api_key_secret =
access_token =
access_token_secret =

# Authenticate with Twitter
auth = tweepy.OAuth1UserHandler(
    consumer_key=api_key,
    consumer_secret=api_key_secret,
    access_token=access_token,
    access_token_secret=access_token_secret
)
api = tweepy.API(auth)

# %%
import tweepy

# Set up client with bearer token
client = tweepy.Client(bearer_token='')

# Define the query to target machine learning and AI-related hashtags
query = "#machinelearning OR #artificialintelligence -is:retweet"  # Exclude retweets

# Function to fetch tweets with pagination
def fetch_tweets(query, max_tweets):
    all_tweets = []
    next_token = None

    while len(all_tweets) < max_tweets:
        # Fetch tweets
        tweets = client.search_recent_tweets(
            query=query,
            tweet_fields=["id", "author_id", "text"],
            max_results=100,  # max allowed in one request
            next_token=next_token
        )

        # Add tweets to the list
        if tweets.data:
            all_tweets.extend(tweets.data)

        # If there are more tweets, get the next token for pagination
        next_token = tweets.meta.get('next_token') if 'next_token' in tweets.meta else None

        # Break if no next_token is available (i.e., no more tweets to fetch)
        if not next_token:
            break

    return all_tweets

# Fetch up to 1000 tweets
tweets = fetch_tweets(query, 1000)

# Print tweet ID, username, and text if data is available
for tweet in tweets:
    user = client.get_user(id=tweet.author_id)  # Fetch user details by author_id
    print(f"Tweet ID: {tweet.id}, Username: {user.data.username}, Tweet: {tweet.text}")
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-81-25ce90bf5d7b> in <cell line: 0>()
#      35
#      36 # Fetch up to 1000 tweets
# ---> 37 tweets = fetch_tweets(query, 1000)
#      38
#      39 # Print tweet ID, username, and text if data is available
#
# <ipython-input-81-25ce90bf5d7b> in fetch_tweets(query, max_tweets)
#      14     while len(all_tweets) < max_tweets:
#      15         # Fetch tweets
# ---> 16         tweets = client.search_recent_tweets(
#      17             query=query,
#      18             tweet_fields=["id", "author_id", "text"],
#
# /usr/local/lib/python3.11/dist-packages/tweepy/client.py in search_recent_tweets(self, query, user_auth, **params)
#    1268         """
#    1269         params["query"] = query
# -> 1270         return self._make_request(
#    1271             "GET", "/2/tweets/search/recent", params=params,
#    1272             endpoint_parameters=(
#
# /usr/local/lib/python3.11/dist-packages/tweepy/client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     127         request_params = self._process_params(params, endpoint_parameters)
#     128
# --> 129         response = self.request(method, route, params=request_params,
#     130                                 json=json, user_auth=user_auth)
#     131
#
# /usr/local/lib/python3.11/dist-packages/tweepy/client.py in request(self, method, route, params, json, user_auth)
#     113                     return self.request(method, route, params, json, user_auth)
#     114                 else:
# --> 115                     raise TooManyRequests(response)
#     116             if response.status_code >= 500:
#     117                 raise TwitterServerError(response)
#
# TooManyRequests: 429 Too Many Requests
# Too Many Requests

# %%
import pandas as pd

# Function to clean tweet data
def clean_data(tweets):
    # Create an empty list to store cleaned data
    cleaned_data = []

    # Iterate through each tweet and clean
    for tweet in tweets:
        tweet_id = tweet.id
        username = tweet.author_id  # username will be fetched later
        text = tweet.text

        # Perform basic text cleaning: remove unwanted spaces, special characters
        text = text.strip()  # Remove leading/trailing whitespaces

        # Append the cleaned data to the list
        cleaned_data.append([tweet_id, username, text])

    # Create a DataFrame from the cleaned data
    df = pd.DataFrame(cleaned_data, columns=["tweet_id", "author_id", "text"])

    # Remove duplicates based on tweet ID or text
    df = df.drop_duplicates(subset=["tweet_id", "text"], keep="first")

    # Drop any rows with missing values (if any)
    df = df.dropna(subset=["tweet_id", "author_id", "text"])

    # Ensure consistency, e.g., removing excessive spaces in text
    df["text"] = df["text"].apply(lambda x: ' '.join(x.split()))  # Remove extra spaces between words

    return df

# Fetch tweets and clean data
tweets = fetch_tweets(query, 1000)

# Clean the data
cleaned_df = clean_data(tweets)

# Save the cleaned data to a CSV file
cleaned_df.to_csv("cleaned_tweets.csv", index=False)

print("Cleaned data has been saved to 'cleaned_tweets.csv'.")
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-82-731d166129a2> in <cell line: 0>()
#      33
#      34 # Fetch tweets and clean data
# ---> 35 tweets = fetch_tweets(query, 1000)  # Assuming `fetch_tweets` function is already defined
#      36
#      37 # Clean the data
#
# <ipython-input-81-25ce90bf5d7b> in fetch_tweets(query, max_tweets)
#      14     while len(all_tweets) < max_tweets:
#      15         # Fetch tweets
# ---> 16         tweets = client.search_recent_tweets(
#      17             query=query,
#      18             tweet_fields=["id", "author_id", "text"],
#
# /usr/local/lib/python3.11/dist-packages/tweepy/client.py in search_recent_tweets(self, query, user_auth, **params)
#    1268         """
#    1269         params["query"] = query
# -> 1270         return self._make_request(
#    1271             "GET", "/2/tweets/search/recent", params=params,
#    1272             endpoint_parameters=(
#
# /usr/local/lib/python3.11/dist-packages/tweepy/client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     127         request_params = self._process_params(params, endpoint_parameters)
#     128
# --> 129         response = self.request(method, route, params=request_params,
#     130                                 json=json, user_auth=user_auth)
#     131
#
# /usr/local/lib/python3.11/dist-packages/tweepy/client.py in request(self, method, route, params, json, user_auth)
#     113                     return self.request(method, route, params, json, user_auth)
#     114                 else:
# --> 115                     raise TooManyRequests(response)
#     116             if response.status_code >= 500:
#     117                 raise TwitterServerError(response)
#
# TooManyRequests: 429 Too Many Requests
# Too Many Requests

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
"""
Processing large datasets can be challenging due to extended runtimes and occasional crashes, making it important to efficiently manage and optimize code for better performance. It's valuable to gain a thorough understanding of these concepts.
Also, coming to 5th question the code was giving time out error  too many requests
"""
# Out:
# "\nProcessing large datasets can be challenging due to extended runtimes and occasional crashes, making it important to efficiently manage and optimize code for better performance. It's valuable to gain a thorough understanding of these concepts.\nAlso, coming to 5th question the code was giving time out error  too many requests\n"

# %% [markdown]
# # Write your response below
# Fill out survey and provide your valuable feedback.
#
# https://docs.google.com/forms/d/e/1FAIpQLSd_ObuA3iNoL7Az_C-2NOfHodfKCfDzHZtGRfIker6WyZqTtA/viewform?usp=dialog
